# %% [markdown]
# # Research Question 1:
#
# The goal: for each ecoregion, estimate how strongly and in which direction pre-season climate anomaly predicts fire season onset timing (β, days/°C), using statsmodels.MixedLM with partial pooling across ecoregions.

# %% [markdown]
# ## 0. Setup
# ### 0.1 Imports

# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import seaborn as sns
from statsmodels.regression.mixed_linear_model import MixedLM
from statsmodels.tools.sm_exceptions import ConvergenceWarning
from scipy.stats import spearmanr
from scipy.stats import t as t_dist
import json
from shapely.geometry import shape
import geopandas as gpd

import os
import warnings
import logging
print('Libraries loaded.')

pd.set_option('display.expand_frame_repr', False)
# Out:
# Libraries loaded.

# %% [markdown]
# ### 0.2 Run Configuration

# %%
# !!!IMPORTANT!!! 
# Folders and some file names are dependent on this

RUN_LABEL   = 'global'  # short name for this run
RUN_VERSION = 'v6'         # increment this for each new run
RUN_NAME   = f'{RUN_LABEL}_{RUN_VERSION}'

# %% [markdown]
# ### 0.3 Paths

# %%
RESPONSE_VARS  = ['onset_doy', 'peak_doy', 'end_doy', 'season_length']
LAG_WINDOWS    = [30, 45, 60, 90]
PREDICTOR_SETS = {
    'temp':      ['temp_anomaly_{lag}d'],
    'precip':    ['precip_anomaly_{lag}d'],
    'both':      ['temp_anomaly_{lag}d', 'precip_anomaly_{lag}d'],
}
GROUP_COL = 'eco_id'

# File paths

BASE_OUT_DIR = 'C:/Users/ibekar/Documents/GitProjects/TGPF' # Windows
# BASE_OUT_DIR = '/Users/ibekar/Github/TGPF'                  # Mac

input_dir_processed = os.path.join(BASE_OUT_DIR, 'runs', RUN_NAME, 'inputs')
results_dir = os.path.join(BASE_OUT_DIR, 'runs', RUN_NAME, 'outputs', 'RQ1')
plot_dir = os.path.join(BASE_OUT_DIR, 'runs', RUN_NAME, 'outputs', 'RQ1', 'plots')
os.makedirs(results_dir, exist_ok=True)
os.makedirs(plot_dir, exist_ok=True)

print(f'Base output directory: {BASE_OUT_DIR}')
print(f'Input directory: {input_dir_processed}')
print(f'Results directory: {results_dir}')
print(f'Plot directory: {plot_dir}')
# Out:
# Base output directory: C:/Users/ibekar/Documents/GitProjects/TGPF
# Input directory: C:/Users/ibekar/Documents/GitProjects/TGPF\runs\global_v6\inputs
# Results directory: C:/Users/ibekar/Documents/GitProjects/TGPF\runs\global_v6\outputs\RQ1
# Plot directory: C:/Users/ibekar/Documents/GitProjects/TGPF\runs\global_v6\outputs\RQ1\plots

# %% [markdown]
# ## 1. Data Loading

# %%
# Load geometries

geo_path = os.path.join(BASE_OUT_DIR, 'runs', RUN_NAME, 'eco_geometries.json')

with open(geo_path) as f:
    data = json.load(f)

gdf = gpd.GeoDataFrame(
    [{'eco_id': d['eco_id'], 'eco_name': d['eco_name']} for d in data],
    geometry=[shape(d['geometry']) for d in data],
    crs='EPSG:4326'
)
print(f'Loaded {len(gdf)} ecoregion geometries.')
# Out:
# Loaded 846 ecoregion geometries.

# %%
# Load main file
df = pd.read_csv(os.path.join(input_dir_processed, 'era5_anomalies_by_lag.csv'))
print(df)
# Out:
#        eco_id                        eco_name  biome_num                                      biome_name  year  onset_doy  peak_doy  end_doy  season_length  n_detections  ...  mean_profile_corr  cv_peak_doy  temp_anomaly_30d  precip_anomaly_30d  temp_anomaly_45d  precip_anomaly_45d  temp_anomaly_60d  precip_anomaly_60d  temp_anomaly_90d  precip_anomaly_90d
# 0           1  Albertine Rift montane forests          1  Tropical & Subtropical Moist Broadleaf Forests  2003         35       193      278            244         26772  ...             0.6949       0.1135          0.070401            0.436633         -0.148986            0.258227         -0.137756            0.789682         -0.175300            0.788038
# 1           1  Albertine Rift montane forests          1  Tropical & Subtropical Moist Broadleaf Forests  2004         43       186      274            232         36852  ...             0.6949       0.1135         -0.183076            0.183724          0.118395           -0.329260          0.137116           -0.520779          0.096936           -0.208620
# 2           1  Albertine Rift montane forests          1  Tropical & Subtropical Moist Broadleaf Forests  2005         22       195      288            267         31512  ...             0.6949       0.1135          0.163124           -1.304048          0.137944           -0.969478          0.041969           -0.720020         -0.050983           -0.430535
# 3           1  Albertine Rift montane forests          1  Tropical & Subtropical Moist Broadleaf Forests  2006         30       249      279            250         28581  ...             0.6949       0.1135          0.178089            0.103682          0.326801           -0.975626          0.283997           -0.964182          0.248226           -1.064302
# 4           1  Albertine Rift montane forests          1  Tropical & Subtropical Moist Broadleaf Forests  2007         52       240      277            226         23681  ...             0.6949       0.1135         -0.324089            1.631099         -0.303887            1.125573         -0.408080            0.922534         -0.459990            1.185035
# ...       ...                             ...        ...                                             ...   ...        ...       ...      ...            ...           ...  ...                ...          ...               ...                 ...               ...                 ...               ...                 ...               ...                 ...
# 14880     845              West Sahara desert         13                      Deserts & Xeric Shrublands  2021         35       227      334            300          3347  ...             0.4410       0.2725          2.469213           -0.102487          1.782920           -0.076862          1.580793           -0.084252          1.393408           -0.075008
# 14881     845              West Sahara desert         13                      Deserts & Xeric Shrublands  2022         45       226      281            237          4351  ...             0.4410       0.2725         -0.593355           -0.062284         -0.334471           -0.056487          0.406982           -0.053709         -0.037997           -0.006650
# 14882     845              West Sahara desert         13                      Deserts & Xeric Shrublands  2023         46       229      324            279          1274  ...             0.4410       0.2725         -1.509426           -0.068784         -0.474969           -0.058148          0.200964           -0.061518          1.193467           -0.073797
# 14883     845              West Sahara desert         13                      Deserts & Xeric Shrublands  2024         83       218      348            266          1674  ...             0.4410       0.2725          0.793411           -0.065088          1.650090           -0.076000          1.359887           -0.074441          1.669595           -0.075715
# 14884     845              West Sahara desert         13                      Deserts & Xeric Shrublands  2025         25       248      350            326          2681  ...             0.4410       0.2725          0.038383           -0.066692          0.150213           -0.080677          0.462967           -0.074391          1.384079           -0.071639
#
# [14885 rows x 23 columns]

# %%
print(df[df.isnull().any(axis=1)])

# NA Check 
null_counts = df.isnull().sum()
null_counts = null_counts[null_counts > 0]
if null_counts.empty:
    print("There is no NA")
else:
    print(null_counts)
# Out:
#        eco_id                                           eco_name  biome_num                                      biome_name  year  onset_doy  peak_doy  end_doy  season_length  n_detections  ...  mean_profile_corr  cv_peak_doy  temp_anomaly_30d  precip_anomaly_30d  temp_anomaly_45d  precip_anomaly_45d  temp_anomaly_60d  precip_anomaly_60d  temp_anomaly_90d  precip_anomaly_90d
# 568        27            São Tomé, Príncipe, and Annobón forests          1  Tropical & Subtropical Moist Broadleaf Forests  2010        139       159      246            108            21  ...             0.2111          NaN         -0.087451           -3.771127          0.251547           -3.800409          0.267689           -3.070744          0.405661           -2.226400
# 6372      360           Northern Pacific Alaskan coastal forests          5                       Temperate Conifer Forests  2005        119       126      129             11            85  ...             0.2297          NaN          1.498171            0.306738          1.095526           -0.568894          2.115877            0.901184          1.708327            1.331677
# 7345      421                            Torngat Mountain tundra         11                                          Tundra  2022        159       161      160              2           152  ...             1.0000          NaN          0.557015           -0.038317         -0.623647           -0.122716         -0.062585           -0.081335          1.026511           -0.104368
# 11155     631                      Tongan tropical moist forests          1  Tropical & Subtropical Moist Broadleaf Forests  2008         67       177      325            259            24  ...             0.1728       0.6337               NaN                 NaN               NaN                 NaN               NaN                 NaN               NaN                 NaN
# 11156     631                      Tongan tropical moist forests          1  Tropical & Subtropical Moist Broadleaf Forests  2011         35       305      341            307            20  ...             0.1728       0.6337               NaN                 NaN               NaN                 NaN               NaN                 NaN               NaN                 NaN
# 11157     631                      Tongan tropical moist forests          1  Tropical & Subtropical Moist Broadleaf Forests  2014         27       360      363            337            20  ...             0.1728       0.6337               NaN                 NaN               NaN                 NaN               NaN                 NaN               NaN                 NaN
# 11158     631                      Tongan tropical moist forests          1  Tropical & Subtropical Moist Broadleaf Forests  2016         33        34      336            304            24  ...             0.1728       0.6337               NaN                 NaN               NaN                 NaN               NaN                 NaN               NaN                 NaN
# 11159     631                      Tongan tropical moist forests          1  Tropical & Subtropical Moist Broadleaf Forests  2019         32       171      354            323            24  ...             0.1728       0.6337               NaN                 NaN               NaN                 NaN               NaN                 NaN               NaN                 NaN
# 11160     631                      Tongan tropical moist forests          1  Tropical & Subtropical Moist Broadleaf Forests  2021         49        52      327            279           171  ...             0.1728       0.6337               NaN                 NaN               NaN                 NaN               NaN                 NaN               NaN                 NaN
# 11161     631                      Tongan tropical moist forests          1  Tropical & Subtropical Moist Broadleaf Forests  2022         17       258      321            305            31  ...             0.1728       0.6337               NaN                 NaN               NaN                 NaN               NaN                 NaN               NaN                 NaN
# 13276     754       Karakoram-West Tibetan Plateau alpine steppe         10                 Montane Grasslands & Shrublands  2013        208       207      308            101            34  ...             0.1840          NaN         -0.411669           -0.483320         -0.718743           -0.071237         -0.328976           -0.284364         -0.383091            0.010124
# 13277     755                    Khangai Mountains alpine meadow         10                 Montane Grasslands & Shrublands  2007        148       153      156              9            22  ...             0.3088          NaN          1.589636           -0.022170          0.630463            0.297303          0.693570            0.167268          0.503315            0.089386
# 13321     759  North Tibetan Plateau-Kunlun Mountains alpine ...         10                 Montane Grasslands & Shrublands  2025        166       217      230             65            22  ...             0.2081          NaN          0.716564           -0.217300          1.477632           -0.110193          1.390200           -0.100760          0.777473           -0.131486
# 13612     778                              Russian Arctic desert         11                                          Tundra  2024        222       219      222              1         28989  ...             0.3316          NaN          1.138270           -0.348861          1.029522           -0.013095          0.868886           -0.084753          0.552532           -0.026276
# 14554     825                    Gobi Lakes Valley desert steppe         13                      Deserts & Xeric Shrublands  2009         60        58       83             24            25  ...             0.4691          NaN          0.878097           -0.061700          0.902169           -0.062206          0.512401           -0.054639          0.512302            0.000158
# 14814     839                    Saharan Atlantic coastal desert         13                      Deserts & Xeric Shrublands  2020         88       149      323            236            33  ...             0.1590          NaN          0.802213           -0.015190          1.930016           -0.033515          2.340764           -0.054008          1.416001           -0.061677
# 14861     844      Tibesti-Jebel Uweinat montane xeric woodlands         13                      Deserts & Xeric Shrublands  2005         50        47       50              1            20  ...             0.2681          NaN          1.870683           -0.002628          0.093279           -0.004021          0.408940           -0.003419          0.128586           -0.002849
#
# [17 rows x 23 columns]
# cv_peak_doy           10
# temp_anomaly_30d       7
# precip_anomaly_30d     7
# temp_anomaly_45d       7
# precip_anomaly_45d     7
# temp_anomaly_60d       7
# precip_anomaly_60d     7
# temp_anomaly_90d       7
# precip_anomaly_90d     7
# dtype: int64

# %%
# Drop NA
df = df.dropna(subset=[col for col in df.columns if 'anomaly' in col])

# Sanity check 
null_counts = df.isnull().sum()
null_counts = null_counts[null_counts > 0]
if null_counts.empty:
    print("There is no NA")
else:
    print(null_counts)
# Out:
# cv_peak_doy    10
# dtype: int64

# %% [markdown]
# ## 2. Model Fitting
# ### 2.1 MixedLM Function

# %%
# Model fitting function

def fit_mixedlm(df, response, predictors, group_col):
    df_subset = df[[response] + predictors + [group_col]].dropna()

    # Standardize predictors
    scaler_parameters = {}
    for predictor in predictors:
        mean = df_subset[predictor].mean()
        std = df_subset[predictor].std()
        df_subset[predictor + '_z'] = (df_subset[predictor] - mean) / std
        scaler_parameters[predictor] = {
            'mean': mean,
            'std': std
        }

    z_predictors = [pred + '_z' for pred in predictors]
    formula = response + ' ~ ' + ' + '.join(z_predictors)
    re_formula = ' ~ ' + ' + '.join(z_predictors)
    fallback = False

    try:
        model = MixedLM.from_formula(formula, groups=df_subset[group_col], re_formula=re_formula, data=df_subset)
        results = model.fit(reml=False)
        convergence_ok = results.converged
    except Exception as e:
        print(f"Model fitting failed for {response} with predictors {predictors}. Attempting fallback to random intercept only.")
        fallback = True
        model = MixedLM.from_formula(formula, groups=df_subset[group_col], data=df_subset)
        results = model.fit()
        convergence_ok = results.converged

    # Extract fixed effects
    ci = results.conf_int()
    fixed_effects = {}
    for zp in z_predictors:
        original_name = zp[:-2]  # Remove '_z' suffix
        coef = results.params[zp]
        se = results.bse[zp]
        pval = results.pvalues[zp]
        ci_low = ci.loc[zp, 0]
        ci_hi = ci.loc[zp, 1]

        fixed_effects[original_name] = {
            'coef' : coef,
            'se'   : se,
            'pval' : pval,
            'ci_low': ci_low,
            'ci_hi' : ci_hi,
        }

    # get eco_id and re_dict for random effects
    random_effects = []
    for group, re_params in results.random_effects.items():
        row = {'eco_id': group}
        for zp in z_predictors:
            total_slope = fixed_effects[zp[:-2]]['coef'] + re_params.get(zp, 0)
            row[zp[:-2] + '_slope'] = total_slope
        random_effects.append(row)

    # Extract model fit metrics
    aic = results.aic
    log_likelihood = results.llf

    # Back-transform slopes to original units
    for fe in fixed_effects:
        std = scaler_parameters[fe]['std']
        fixed_effects[fe]['coef_unscaled'] = fixed_effects[fe]['coef'] / std
        fixed_effects[fe]['ci_low_unscaled'] = fixed_effects[fe]['ci_low'] / std
        fixed_effects[fe]['ci_hi_unscaled'] = fixed_effects[fe]['ci_hi'] / std

    for row in random_effects:
        for pred in predictors:
            std = scaler_parameters[pred]['std']
            row[pred + '_slope_original'] = row[pred + '_slope'] / std

    return {
        'fixed_effects':  fixed_effects,
        'random_effects': random_effects,
        'aic':            aic,
        'log_likelihood': log_likelihood,
        'fallback':       fallback,
        'response':       response,
        'predictors':     predictors,
        'convergence_ok': convergence_ok,
        }

# %% [markdown]
# ### 2.2 Convergence Logging

# %%
# Remove existing handlers otherwise warning txt file will be appending all
root_logger = logging.getLogger()
for handler in root_logger.handlers[:]:
    root_logger.removeHandler(handler)
    handler.close()

# Now basicConfig will take effect
logging.basicConfig(
    filename = os.path.join(results_dir, 'RQ1_convergence_log.txt'), 
    level= logging.WARNING,
    format= '%(asctime)s - %(message)s',
    filemode= 'w'
)

warnings.filterwarnings('always', category=ConvergenceWarning)

current_model_context = {}
def custom_warning(msg, *args, **kwargs):
    context = current_model_context
    log_msg = (
        f"response={context.get('response','?')} | "
        f"lag={context.get('lag','?')} | "
        f"pred_set={context.get('pred_set','?')} | "
        f"{str(msg)}"
    )
    logging.warning(log_msg)
    # Short readable print to notebook
    print(f" Convergence issue: {context.get('response','?')} | \
          lag={context.get('lag','?')} | {context.get('pred_set','?')}")

warnings.showwarning = custom_warning

# %% [markdown]
# ### 2.3 Model Loop

# %%
# Modeling loop

all_fixed = []
all_random = []

for response in RESPONSE_VARS:
    for lag in LAG_WINDOWS:
        for pred_set_name, pred_template_list in PREDICTOR_SETS.items():

            # Resolve actual column names
            predictors = [p.format(lag=lag) for p in pred_template_list]

            # Progress message
            print(f"Running: response={response} | lag={lag} | pred_set={pred_set_name}")

            #Update the model context for logging
            current_model_context = {'response': response, 'lag': lag, 'pred_set': pred_set_name}

            # Fit model
            run_result = fit_mixedlm(df, response, predictors, GROUP_COL)

            # Build fixed effects summary row
            fixed_row = {
                'response':       response,
                'lag':            lag,
                'pred_set':       pred_set_name,
                'fallback':       run_result['fallback'],
                'convergence_ok': run_result['convergence_ok'],
                'aic':            run_result['aic'],
                'log_likelihood': run_result['log_likelihood'],
            }
            for pred, vals in run_result['fixed_effects'].items():
                fixed_row[pred + '_coef']          = vals['coef']
                fixed_row[pred + '_coef_unscaled'] = vals['coef_unscaled']
                fixed_row[pred + '_se']            = vals['se']
                fixed_row[pred + '_pval']          = vals['pval']
                fixed_row[pred + '_ci_low']        = vals['ci_low']
                fixed_row[pred + '_ci_hi']         = vals['ci_hi']
                fixed_row[pred + '_ci_low_unscaled'] = vals['ci_low_unscaled']
                fixed_row[pred + '_ci_hi_unscaled']  = vals['ci_hi_unscaled']
            all_fixed.append(fixed_row)

            # Build random effects rows
            for row in run_result['random_effects']:
                row['response'] = response
                row['lag']      = lag
                row['pred_set'] = pred_set_name
                all_random.append(row)

print(f"\nDone. {len(all_fixed)} model runs completed.")

# Restore default warning handler so it doesn't bleed into later cells
warnings.showwarning = warnings._showwarning_orig
# Out:
# Running: response=onset_doy | lag=30 | pred_set=temp
# Running: response=onset_doy | lag=30 | pred_set=precip
# Running: response=onset_doy | lag=30 | pred_set=both
#  Convergence issue: onset_doy |           lag=30 | both
#  Convergence issue: onset_doy |           lag=30 | both
#  Convergence issue: onset_doy |           lag=30 | both
#  Convergence issue: onset_doy |           lag=30 | both
#  Convergence issue: onset_doy |           lag=30 | both
#  Convergence issue: onset_doy |           lag=30 | both
#  Convergence issue: onset_doy |           lag=30 | both
#  Convergence issue: onset_doy |           lag=30 | both
# Running: response=onset_doy | lag=45 | pred_set=temp
#  Convergence issue: onset_doy |           lag=45 | temp
#  Convergence issue: onset_doy |           lag=45 | temp
# Running: response=onset_doy | lag=45 | pred_set=precip
# Running: response=onset_doy | lag=45 | pred_set=both
#  Convergence issue: onset_doy |           lag=45 | both
#  Convergence issue: onset_doy |           lag=45 | both
#  Convergence issue: onset_doy |           lag=45 | both
# Running: response=onset_doy | lag=60 | pred_set=temp
#  Convergence issue: onset_doy |           lag=60 | temp
#  Convergence issue: onset_doy |           lag=60 | temp
# Running: response=onset_doy | lag=60 | pred_set=precip
# Running: response=onset_doy | lag=60 | pred_set=both
#  Convergence issue: onset_doy |           lag=60 | both
#  Convergence issue: onset_doy |           lag=60 | both
#  Convergence issue: onset_doy |           lag=60 | both
#  Convergence issue: onset_doy |           lag=60 | both
#  Convergence issue: onset_doy |           lag=60 | both
#  Convergence issue: onset_doy |           lag=60 | both
#  Convergence issue: onset_doy |           lag=60 | both
#  Convergence issue: onset_doy |           lag=60 | both
# Running: response=onset_doy | lag=90 | pred_set=temp
# Running: response=onset_doy | lag=90 | pred_set=precip
# Running: response=onset_doy | lag=90 | pred_set=both
#  Convergence issue: onset_doy |           lag=90 | both
#  Convergence issue: onset_doy |           lag=90 | both
#  Convergence issue: onset_doy |           lag=90 | both
# Running: response=peak_doy | lag=30 | pred_set=temp
# Running: response=peak_doy | lag=30 | pred_set=precip
# Running: response=peak_doy | lag=30 | pred_set=both
#  Convergence issue: peak_doy |           lag=30 | both
#  Convergence issue: peak_doy |           lag=30 | both
# Running: response=peak_doy | lag=45 | pred_set=temp
# Running: response=peak_doy | lag=45 | pred_set=precip
# Running: response=peak_doy | lag=45 | pred_set=both
#  Convergence issue: peak_doy |           lag=45 | both
#  Convergence issue: peak_doy |           lag=45 | both
#  Convergence issue: peak_doy |           lag=45 | both
#  Convergence issue: peak_doy |           lag=45 | both
#  Convergence issue: peak_doy |           lag=45 | both
#  Convergence issue: peak_doy |           lag=45 | both
#  Convergence issue: peak_doy |           lag=45 | both
# Running: response=peak_doy | lag=60 | pred_set=temp
# Running: response=peak_doy | lag=60 | pred_set=precip
# Running: response=peak_doy | lag=60 | pred_set=both
#  Convergence issue: peak_doy |           lag=60 | both
#  Convergence issue: peak_doy |           lag=60 | both
# Running: response=peak_doy | lag=90 | pred_set=temp
#  Convergence issue: peak_doy |           lag=90 | temp
# Running: response=peak_doy | lag=90 | pred_set=precip
# Running: response=peak_doy | lag=90 | pred_set=both
#  Convergence issue: peak_doy |           lag=90 | both
#  Convergence issue: peak_doy |           lag=90 | both
# Running: response=end_doy | lag=30 | pred_set=temp
#  Convergence issue: end_doy |           lag=30 | temp
#  Convergence issue: end_doy |           lag=30 | temp
#  Convergence issue: end_doy |           lag=30 | temp
#  Convergence issue: end_doy |           lag=30 | temp
#  Convergence issue: end_doy |           lag=30 | temp
#  Convergence issue: end_doy |           lag=30 | temp
#  Convergence issue: end_doy |           lag=30 | temp
# Running: response=end_doy | lag=30 | pred_set=precip
# Running: response=end_doy | lag=30 | pred_set=both
#  Convergence issue: end_doy |           lag=30 | both
#  Convergence issue: end_doy |           lag=30 | both
#  Convergence issue: end_doy |           lag=30 | both
#  Convergence issue: end_doy |           lag=30 | both
#  Convergence issue: end_doy |           lag=30 | both
#  Convergence issue: end_doy |           lag=30 | both
#  Convergence issue: end_doy |           lag=30 | both
#  Convergence issue: end_doy |           lag=30 | both
# Running: response=end_doy | lag=45 | pred_set=temp
# Running: response=end_doy | lag=45 | pred_set=precip
# Running: response=end_doy | lag=45 | pred_set=both
#  Convergence issue: end_doy |           lag=45 | both
#  Convergence issue: end_doy |           lag=45 | both
#  Convergence issue: end_doy |           lag=45 | both
#  Convergence issue: end_doy |           lag=45 | both
#  Convergence issue: end_doy |           lag=45 | both
#  Convergence issue: end_doy |           lag=45 | both
#  Convergence issue: end_doy |           lag=45 | both
#  Convergence issue: end_doy |           lag=45 | both
# Running: response=end_doy | lag=60 | pred_set=temp
# Running: response=end_doy | lag=60 | pred_set=precip
# Running: response=end_doy | lag=60 | pred_set=both
#  Convergence issue: end_doy |           lag=60 | both
#  Convergence issue: end_doy |           lag=60 | both
#  Convergence issue: end_doy |           lag=60 | both
#  Convergence issue: end_doy |           lag=60 | both
#  Convergence issue: end_doy |           lag=60 | both
#  Convergence issue: end_doy |           lag=60 | both
#  Convergence issue: end_doy |           lag=60 | both
#  Convergence issue: end_doy |           lag=60 | both
# Running: response=end_doy | lag=90 | pred_set=temp
#  Convergence issue: end_doy |           lag=90 | temp
#  Convergence issue: end_doy |           lag=90 | temp
#  Convergence issue: end_doy |           lag=90 | temp
# Running: response=end_doy | lag=90 | pred_set=precip
# Running: response=end_doy | lag=90 | pred_set=both
#  Convergence issue: end_doy |           lag=90 | both
#  Convergence issue: end_doy |           lag=90 | both
#  Convergence issue: end_doy |           lag=90 | both
#  Convergence issue: end_doy |           lag=90 | both
#  Convergence issue: end_doy |           lag=90 | both
#  Convergence issue: end_doy |           lag=90 | both
#  Convergence issue: end_doy |           lag=90 | both
#  Convergence issue: end_doy |           lag=90 | both
# Running: response=season_length | lag=30 | pred_set=temp
# Running: response=season_length | lag=30 | pred_set=precip
# Running: response=season_length | lag=30 | pred_set=both
#  Convergence issue: season_length |           lag=30 | both
#  Convergence issue: season_length |           lag=30 | both
#  Convergence issue: season_length |           lag=30 | both
#  Convergence issue: season_length |           lag=30 | both
#  Convergence issue: season_length |           lag=30 | both
#  Convergence issue: season_length |           lag=30 | both
#  Convergence issue: season_length |           lag=30 | both
# Running: response=season_length | lag=45 | pred_set=temp
#  Convergence issue: season_length |           lag=45 | temp
#  Convergence issue: season_length |           lag=45 | temp
# Running: response=season_length | lag=45 | pred_set=precip
# Running: response=season_length | lag=45 | pred_set=both
#  Convergence issue: season_length |           lag=45 | both
#  Convergence issue: season_length |           lag=45 | both
#  Convergence issue: season_length |           lag=45 | both
#  Convergence issue: season_length |           lag=45 | both
#  Convergence issue: season_length |           lag=45 | both
#  Convergence issue: season_length |           lag=45 | both
#  Convergence issue: season_length |           lag=45 | both
# Running: response=season_length | lag=60 | pred_set=temp
# Running: response=season_length | lag=60 | pred_set=precip
# Running: response=season_length | lag=60 | pred_set=both
#  Convergence issue: season_length |           lag=60 | both
#  Convergence issue: season_length |           lag=60 | both
#  Convergence issue: season_length |           lag=60 | both
#  Convergence issue: season_length |           lag=60 | both
#  Convergence issue: season_length |           lag=60 | both
#  Convergence issue: season_length |           lag=60 | both
#  Convergence issue: season_length |           lag=60 | both
#  Convergence issue: season_length |           lag=60 | both
# Running: response=season_length | lag=90 | pred_set=temp
#  Convergence issue: season_length |           lag=90 | temp
#  Convergence issue: season_length |           lag=90 | temp
# Running: response=season_length | lag=90 | pred_set=precip
# Running: response=season_length | lag=90 | pred_set=both
#  Convergence issue: season_length |           lag=90 | both
#  Convergence issue: season_length |           lag=90 | both
#  Convergence issue: season_length |           lag=90 | both
#  Convergence issue: season_length |           lag=90 | both
#  Convergence issue: season_length |           lag=90 | both
#  Convergence issue: season_length |           lag=90 | both
#  Convergence issue: season_length |           lag=90 | both
#  Convergence issue: season_length |           lag=90 | both
#
# Done. 48 model runs completed.

# %% [markdown]
# ## 3. Results
# ### Tidying up

# %%
# Random effects df
df_random = pd.DataFrame(all_random)

id_cols = ["eco_id", "response", "lag", "pred_set"]
value_cols = [col for col in df_random.columns if col.endswith("_slope_original")]

df_random_tidy = df_random.melt(id_vars = id_cols,
                               value_vars = value_cols,
                               var_name = "predictors",
                               value_name = "slope").dropna(subset="slope")

df_random_tidy["predictors"] = df_random_tidy["predictors"].str.replace("_slope_original", "")

print(df_random_tidy)
# Out:
#         eco_id       response  lag pred_set          predictors     slope
# 0            1      onset_doy   30     temp    temp_anomaly_30d -2.619303
# 1            2      onset_doy   30     temp    temp_anomaly_30d -1.285667
# 2            3      onset_doy   30     temp    temp_anomaly_30d -2.317395
# 3            4      onset_doy   30     temp    temp_anomaly_30d -5.047380
# 4            5      onset_doy   30     temp    temp_anomaly_30d -1.870160
# ...        ...            ...  ...      ...                 ...       ...
# 271099     839  season_length   90     both  precip_anomaly_90d -0.366143
# 271100     840  season_length   90     both  precip_anomaly_90d  1.291048
# 271101     843  season_length   90     both  precip_anomaly_90d  0.304865
# 271102     844  season_length   90     both  precip_anomaly_90d -3.350547
# 271103     845  season_length   90     both  precip_anomaly_90d  0.868289
#
# [45184 rows x 6 columns]

# %%
# Fixed effects df
df_fixed  = pd.DataFrame(all_fixed)

fixed_id_cols = ['response', 'lag', 'pred_set', 'fallback', 'convergence_ok', 'aic', 
                 'log_likelihood']
metrics = ['coef', 'coef_unscaled', 'se', 'pval', 'ci_low', 'ci_hi', 'ci_low_unscaled', 
           'ci_hi_unscaled']

tidy_parts = []
for metric in metrics:
    value_cols_fixed = [col for col in df_fixed.columns if col.endswith(f'_{metric}')]
    melted = df_fixed.melt(
        id_vars=fixed_id_cols,
        value_vars=value_cols_fixed,
        var_name='predictor',
        value_name=metric
    ).dropna(subset=metric)
    melted['predictor'] = melted['predictor'].str.replace(f'_{metric}', '', regex=False)
    tidy_parts.append(melted)

# Merge all metrics together on common columns
merge_cols = fixed_id_cols + ['predictor']
df_fixed_tidy = tidy_parts[0]
for part in tidy_parts[1:]:
    df_fixed_tidy = df_fixed_tidy.merge(part, on=merge_cols, how='outer')

print(df_fixed_tidy)
# Out:
#          response  lag pred_set  fallback  convergence_ok            aic  log_likelihood           predictor      coef  coef_unscaled        se          pval    ci_low     ci_hi  ci_low_unscaled  ci_hi_unscaled
# 0         end_doy   30     both     False           False  155427.190073   -77703.595037  precip_anomaly_30d  4.805810       3.971570  0.621378  1.041185e-14  3.587933  6.023688         2.965104        4.978037
# 1         end_doy   30     both     False           False  155427.190073   -77703.595037    temp_anomaly_30d -2.211915      -1.687907  0.633044  4.756771e-04 -3.452660 -0.971171        -2.634716       -0.741098
# 2         end_doy   30   precip     False            True  154990.433333   -77489.216666  precip_anomaly_30d  5.218684       4.312774  0.529395  6.341168e-23  4.181088  6.256280         3.455294        5.170254
# 3         end_doy   30     temp     False           False  155201.719900   -77594.859950    temp_anomaly_30d -1.979173      -1.510302  0.374088  1.218745e-07 -2.712372 -1.245974        -2.069805       -0.950800
# 4         end_doy   45     both     False           False  155402.136060   -77691.068030  precip_anomaly_45d  5.130707       4.852193  0.620231  1.314570e-16  3.915076  6.346338         3.702551        6.001835
# ..            ...  ...      ...       ...             ...            ...             ...                 ...       ...            ...       ...           ...       ...       ...              ...             ...
# 59  season_length   60     temp     False            True  162473.927531   -81230.963766    temp_anomaly_60d  1.997366       1.835987  0.435823  4.584078e-06  1.143168  2.851563         1.050805        2.621169
# 60  season_length   90     both     False           False  162262.018667   -81121.009334  precip_anomaly_90d -0.600423      -0.659812  0.781866  4.425249e-01 -2.132852  0.932006        -2.343814        1.024191
# 61  season_length   90     both     False           False  162262.018667   -81121.009334    temp_anomaly_90d  2.136113       2.193121  0.473975  6.581106e-06  1.207139  3.065087         1.239355        3.146887
# 62  season_length   90   precip     False            True  162261.509184   -81124.754592  precip_anomaly_90d -0.964562      -1.059967  0.747985  1.972079e-01 -2.430585  0.501461        -2.670996        0.551061
# 63  season_length   90     temp     False            True  162471.102159   -81229.551080    temp_anomaly_90d  2.140767       2.197898  0.451974  2.174593e-06  1.254914  3.026619         1.288405        3.107392
#
# [64 rows x 16 columns]

# %%
# Save em all
df_fixed_tidy.to_csv(os.path.join(results_dir, 'RQ1_fixed_effects_tidy.csv'), index=False)
df_random_tidy.to_csv(os.path.join(results_dir, 'RQ1_random_effects_tidy.csv'), index=False)

print(f'Fixed effects table:  {df_fixed.shape}')
print(f'Random effects table: {df_random.shape}')
# Out:
# Fixed effects table:  (48, 71)
# Random effects table: (33888, 20)

# %% [markdown]
# ### Quick Inspection

# %%
# Check how many runs converged
df_converged = df_fixed_tidy[df_fixed_tidy['convergence_ok'] == True]
print(f'{len(df_converged)} converged runs out of 48')
# Out:
# 41 converged runs out of 48

# %%
# See temp runs
temp_runs = df_fixed_tidy[
    (df_fixed_tidy['pred_set'] == 'temp')]\
        [['response', 'lag', 'predictor', 'coef_unscaled', 'pval', 'convergence_ok']]

print(temp_runs.to_string())
# Out:
#          response  lag         predictor  coef_unscaled          pval  convergence_ok
# 3         end_doy   30  temp_anomaly_30d      -1.510302  1.218745e-07           False
# 7         end_doy   45  temp_anomaly_45d      -1.602196  1.446142e-07            True
# 11        end_doy   60  temp_anomaly_60d      -1.746235  1.800291e-07            True
# 15        end_doy   90  temp_anomaly_90d      -2.517586  1.839512e-10            True
# 19      onset_doy   30  temp_anomaly_30d      -2.980000  4.126209e-37            True
# 23      onset_doy   45  temp_anomaly_45d      -3.280609  1.540770e-26            True
# 27      onset_doy   60  temp_anomaly_60d      -3.458721  9.285231e-19            True
# 31      onset_doy   90  temp_anomaly_90d      -3.661463  1.172102e-27            True
# 35       peak_doy   30  temp_anomaly_30d      -2.432390  7.124744e-07            True
# 39       peak_doy   45  temp_anomaly_45d      -2.504664  1.951945e-06            True
# 43       peak_doy   60  temp_anomaly_60d      -3.002627  4.704104e-07            True
# 47       peak_doy   90  temp_anomaly_90d      -3.246119  6.371287e-07            True
# 51  season_length   30  temp_anomaly_30d       1.574165  3.552958e-06            True
# 55  season_length   45  temp_anomaly_45d       1.752323  2.443944e-06            True
# 59  season_length   60  temp_anomaly_60d       1.835987  4.584078e-06            True
# 63  season_length   90  temp_anomaly_90d       2.197898  2.174593e-06            True

# %%
# See precipitation runs
precip_runs = df_fixed_tidy[
    (df_fixed_tidy['pred_set'] == 'precip')]\
        [['response', 'lag', 'predictor', 'coef_unscaled', 'pval', 'convergence_ok']]

print(precip_runs.to_string())
# Out:
#          response  lag           predictor  coef_unscaled          pval  convergence_ok
# 2         end_doy   30  precip_anomaly_30d       4.312774  6.341168e-23            True
# 6         end_doy   45  precip_anomaly_45d       5.401301  6.613621e-25            True
# 10        end_doy   60  precip_anomaly_60d       6.246852  1.016623e-25            True
# 14        end_doy   90  precip_anomaly_90d       6.822899  2.086039e-27            True
# 18      onset_doy   30  precip_anomaly_30d       5.914576  1.264131e-42            True
# 22      onset_doy   45  precip_anomaly_45d       6.700906  2.390883e-44            True
# 26      onset_doy   60  precip_anomaly_60d       6.872394  9.594520e-48            True
# 30      onset_doy   90  precip_anomaly_90d       7.558666  1.048876e-53            True
# 34       peak_doy   30  precip_anomaly_30d       4.729516  2.288053e-14            True
# 38       peak_doy   45  precip_anomaly_45d       6.043324  1.253964e-16            True
# 42       peak_doy   60  precip_anomaly_60d       6.515098  5.182414e-17            True
# 46       peak_doy   90  precip_anomaly_90d       6.788948  3.033696e-17            True
# 50  season_length   30  precip_anomaly_30d      -1.457113  2.341356e-02            True
# 54  season_length   45  precip_anomaly_45d      -1.321410  6.254474e-02            True
# 58  season_length   60  precip_anomaly_60d      -1.007031  1.942411e-01            True
# 62  season_length   90  precip_anomaly_90d      -1.059967  1.972079e-01            True

# %%
# Fixed effect significance summary
sig_df = df_fixed_tidy[df_fixed_tidy['pred_set'] != 'both'].copy()

sig_df['significant']    = sig_df['pval'] < 0.05
sig_df['ci_excl_zero']   = (sig_df['ci_low'] > 0) | (sig_df['ci_hi'] < 0)

summary = sig_df.groupby(['pred_set', 'response', 'lag'])[
    ['significant', 'ci_excl_zero', 'convergence_ok']
].first().reset_index()

print(summary.to_string())
# Out:
#    pred_set       response  lag  significant  ci_excl_zero  convergence_ok
# 0    precip        end_doy   30         True          True            True
# 1    precip        end_doy   45         True          True            True
# 2    precip        end_doy   60         True          True            True
# 3    precip        end_doy   90         True          True            True
# 4    precip      onset_doy   30         True          True            True
# 5    precip      onset_doy   45         True          True            True
# 6    precip      onset_doy   60         True          True            True
# 7    precip      onset_doy   90         True          True            True
# 8    precip       peak_doy   30         True          True            True
# 9    precip       peak_doy   45         True          True            True
# 10   precip       peak_doy   60         True          True            True
# 11   precip       peak_doy   90         True          True            True
# 12   precip  season_length   30         True          True            True
# 13   precip  season_length   45        False         False            True
# 14   precip  season_length   60        False         False            True
# 15   precip  season_length   90        False         False            True
# 16     temp        end_doy   30         True          True           False
# 17     temp        end_doy   45         True          True            True
# 18     temp        end_doy   60         True          True            True
# 19     temp        end_doy   90         True          True            True
# 20     temp      onset_doy   30         True          True            True
# 21     temp      onset_doy   45         True          True            True
# 22     temp      onset_doy   60         True          True            True
# 23     temp      onset_doy   90         True          True            True
# 24     temp       peak_doy   30         True          True            True
# 25     temp       peak_doy   45         True          True            True
# 26     temp       peak_doy   60         True          True            True
# 27     temp       peak_doy   90         True          True            True
# 28     temp  season_length   30         True          True            True
# 29     temp  season_length   45         True          True            True
# 30     temp  season_length   60         True          True            True
# 31     temp  season_length   90         True          True            True

# %% [markdown]
# ## 4. Visualisation

# %%
# Load results from disk (skip re-running models)
if 'df_fixed_tidy' not in locals():
    df_fixed_tidy = pd.read_csv(os.path.join(results_dir, 'RQ1_fixed_effects_tidy.csv'))
    print(f'Fixed effects loaded from disk: {df_fixed_tidy.shape}')
else:
    print(f'Fixed effects already in environment: {df_fixed_tidy.shape}')

if 'df_random_tidy' not in locals():
    df_random_tidy = pd.read_csv(os.path.join(results_dir, 'RQ1_random_effects_tidy.csv'))
    print(f'Random effects loaded from disk: {df_random_tidy.shape}')
else:
    print(f'Random effects already in environment: {df_random_tidy.shape}')

# %% [markdown]
# ### 4.1 Heatmap: Fixed Effects

# %%
temp_df   = df_fixed_tidy[(df_fixed_tidy['pred_set'] == 'temp')].copy()
precip_df = df_fixed_tidy[(df_fixed_tidy['pred_set'] == 'precip')].copy()

pivot_temp   = temp_df.pivot(index='response',   columns='lag', values='coef_unscaled')
pivot_precip = precip_df.pivot(index='response', columns='lag', values='coef_unscaled')

mask_temp   = ~temp_df.pivot(index='response',   columns='lag', 
                             values='convergence_ok').astype(bool)
mask_precip = ~precip_df.pivot(index='response', columns='lag', 
                               values='convergence_ok').astype(bool)

def make_annot(pivot, mask):
    annot = pivot.map(lambda v: f'{v:.2f}')
    annot[mask] = annot[mask] + '*'
    return annot

annot_temp   = make_annot(pivot_temp, mask_temp)
annot_precip = make_annot(pivot_precip, mask_precip)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.heatmap(
    pivot_temp, annot=annot_temp, fmt='',
    cmap='RdBu', center=0,
    ax=axes[0], cbar=False
)
axes[0].set_title('Temperature slope (days/°C)')
axes[0].set_xlabel('Lag window (days)')
axes[0].set_ylabel('Response variable')

sns.heatmap(
    pivot_precip, annot=annot_precip, fmt='',
    cmap='RdBu', center=0,
    ax=axes[1], cbar=False
)
axes[1].set_title('Precipitation slope (days/mm)')
axes[1].set_xlabel('Lag window (days)')
axes[1].set_ylabel('')

for ax in axes:
    for text in ax.texts:
        if text.get_text().endswith('*'):
            text.set_color('black')

fig.suptitle('Fixed effect slopes by response and lag window\n(* = non-converged)', y=1.02)

plt.tight_layout()
plt.savefig(os.path.join(plot_dir, 'RQ1_01_heatmap_fixed_effects.png'),
            dpi=150, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\2123691783.py:50: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### 4.2 Histogram: Slope Distribution

# %%
def plot_histogram(df_random_tidy, response, lag, pred_set, plot_save_dir, all_lags):
    
    # Compute global x range and max count across all lags
    all_slopes = []
    all_counts = []
    for l in all_lags:
        subset = df_random_tidy[
            (df_random_tidy['response'] == response) &
            (df_random_tidy['lag'] == l) &
            (df_random_tidy['pred_set'] == pred_set) &
            (df_random_tidy['predictors'] == f'{pred_set}_anomaly_{l}d')
        ]
        all_slopes.append(subset['slope'])
        counts, _ = np.histogram(subset['slope'], bins=20)
        all_counts.append(counts.max())
    
    all_slopes = pd.concat(all_slopes)
    x_min = all_slopes.min()
    x_max = all_slopes.max()
    global_max = max(all_counts)

    # Filter to current lag
    plot_df = df_random_tidy[
        (df_random_tidy['response'] == response) &
        (df_random_tidy['lag'] == lag) &
        (df_random_tidy['pred_set'] == pred_set) &
        (df_random_tidy['predictors'] == f'{pred_set}_anomaly_{lag}d')
    ]
    
    unit = '°C' if pred_set == 'temp' else 'mm'

    fig, ax = plt.subplots(figsize=(10, 5))
    ax.hist(plot_df['slope'], bins=20, edgecolor='black')
    ax.set_xlim(x_min - 0.5, x_max + 0.5)
    ax.set_ylim(0, global_max + 1)
    ax.set_xlabel(f'Per-ecoregion slope (days/{unit})')
    ax.set_ylabel('Count')
    ax.set_title(f'Distribution of {pred_set} sensitivity of {response} ({lag}d lag)')
    plt.tight_layout()
    plt.savefig(os.path.join(plot_save_dir, f'RQ1_02_histogram_{response}_{pred_set}_{lag}d.png'), 
                dpi=150, bbox_inches='tight')
    plt.show()

# %%
for pred_set in ["temp", "precip"]:
    for lag in LAG_WINDOWS:
        plot_histogram(df_random_tidy, 'onset_doy', lag, pred_set, plot_dir, LAG_WINDOWS)
# Out:
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\4037055597.py:42: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### 4.3 Forest Plot

# %%
# Define this ONCE before calling plot_forest in your loop
ALL_BIOMES      = sorted(df['biome_name'].dropna().unique())
PALETTE         = plt.cm.tab10.colors
BIOME_COLOR_MAP = {biome: PALETTE[i % len(PALETTE)] for i, biome in enumerate(ALL_BIOMES)}

def plot_forest(df_random_tidy, df, response, lag, pred_set, plot_save_dir, 
                all_lags, biome_color_map):

    # Compute global x range across all lags
    all_slopes = []
    for l in all_lags:
        subset = df_random_tidy[
            (df_random_tidy['response'] == response) &
            (df_random_tidy['lag'] == l) &
            (df_random_tidy['pred_set'] == pred_set) &
            (df_random_tidy['predictors'] == f'{pred_set}_anomaly_{l}d')
        ]
        all_slopes.append(subset['slope'])

    all_slopes = pd.concat(all_slopes)
    x_margin   = (all_slopes.max() - all_slopes.min()) * 0.05
    x_min      = all_slopes.min() - x_margin
    x_max      = all_slopes.max() + x_margin

    # Filter to current lag
    plot_df = df_random_tidy[
        (df_random_tidy['response'] == response) &
        (df_random_tidy['lag'] == lag) &
        (df_random_tidy['pred_set'] == pred_set) &
        (df_random_tidy['predictors'] == f'{pred_set}_anomaly_{lag}d')
    ]

    eco_meta  = df[['eco_id', 'eco_name', 'biome_name']].drop_duplicates()
    forest_df = plot_df[['eco_id', 'slope']].merge(eco_meta, on='eco_id')
    forest_df = forest_df.sort_values('slope')

    colors = [biome_color_map[b] for b in forest_df['biome_name']]

    fig, ax = plt.subplots(figsize=(10, 14))
    ax.barh(range(len(forest_df)), forest_df['slope'], color=colors)
    ax.axvline(0, color='black', linewidth=1)
    ax.set_xlim(x_min, x_max)
    ax.set_yticks(range(len(forest_df)))
    ax.set_yticklabels(forest_df['eco_name'], fontsize=7)
    ax.set_xlabel('Per-ecoregion slope (days/°C)')
    ax.set_title(f'{response} — {pred_set} sensitivity per ecoregion ({lag}d lag)')

    legend_elements = [Patch(facecolor=biome_color_map[b], label=b) for b in biome_color_map]
    ax.legend(handles=legend_elements, fontsize=7, loc='upper left')

    plt.tight_layout()
    plt.savefig(os.path.join(plot_save_dir, f'RQ1_03_forestplot_{response}_{pred_set}_{lag}d.png'),
                dpi=150, bbox_inches='tight')
    plt.show()

# %%
for pred_set in ["temp", "precip"]:
    for lag in LAG_WINDOWS:
        plot_forest(df_random_tidy, df, 'onset_doy', lag, pred_set, plot_dir, LAG_WINDOWS, BIOME_COLOR_MAP)
# Out:
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\2709434540.py:54: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\2709434540.py:54: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\2709434540.py:54: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\2709434540.py:54: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\2709434540.py:54: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\2709434540.py:54: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\2709434540.py:54: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\2709434540.py:54: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### 4.4 Map

# %%
def plot_map(df_random_tidy, df, gdf, response, lag, pred_set, plot_save_dir, all_lags):
    
    # Compute global slope range across all lags for consistent colormap
    all_slopes = []
    for l in all_lags:
        subset = df_random_tidy[
            (df_random_tidy['response'] == response) &
            (df_random_tidy['lag'] == l) &
            (df_random_tidy['pred_set'] == pred_set) &
            (df_random_tidy['predictors'] == f'{pred_set}_anomaly_{l}d')
        ]
        all_slopes.append(subset['slope'])
    
    all_slopes = pd.concat(all_slopes)
    vmin = all_slopes.min()
    vmax = all_slopes.max()

    # Filter to current lag
    plot_df = df_random_tidy[
        (df_random_tidy['response'] == response) &
        (df_random_tidy['lag'] == lag) &
        (df_random_tidy['pred_set'] == pred_set) &
        (df_random_tidy['predictors'] == f'{pred_set}_anomaly_{lag}d')
    ]

    # Merge with metadata and geometries
    eco_meta = df[['eco_id', 'biome_name']].drop_duplicates()
    plot_df = plot_df.merge(eco_meta, on='eco_id')
    map_df = gdf.merge(plot_df[['eco_id', 'slope', 'biome_name']], on='eco_id')

    # Plot
    fig, ax = plt.subplots(figsize=(14, 8))
    map_df.plot(
        column='slope',
        cmap='RdBu',
        legend=True,
        vmin=vmin,
        vmax=vmax,
        legend_kwds={'label': 'Per-ecoregion slope (days/°C)', 'shrink': 0.6},
        edgecolor='black',
        linewidth=0.3,
        ax=ax
    )
    ax.set_title(f'{pred_set} sensitivity of {response} per ecoregion ({lag}d lag)', fontsize=13)
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    plt.tight_layout()
    plt.savefig(os.path.join(plot_save_dir, f'RQ1_04_map_{response}_{pred_set}_{lag}d.png'), 
                dpi=150, bbox_inches='tight')
    plt.show()

# %%
for pred_set in ["temp", "precip"]:
    for lag in LAG_WINDOWS:
        plot_map(df_random_tidy, df, gdf, 'onset_doy', lag, pred_set, plot_dir, LAG_WINDOWS)
# Out:
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\1079514007.py:50: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\1079514007.py:50: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\1079514007.py:50: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\1079514007.py:32: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(14, 8))
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\1079514007.py:50: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\1079514007.py:50: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\1079514007.py:50: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\1079514007.py:50: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\1079514007.py:50: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### 4.6 AIC Comparison

# %%
def plot_aic(df_fixed_tidy, plot_save_dir):

    PRED_ORDER  = ['temp', 'precip', 'both']
    PRED_COLORS = {'temp': '#E57373', 'precip': '#64B5F6', 'both': '#81C784'}
    BAR_WIDTH   = 0.25
    OFFSETS     = [-BAR_WIDTH, 0, BAR_WIDTH]

    fig, axes = plt.subplots(2, 2, figsize=(14, 9), sharey=True)
    axes = axes.flatten()

    # Compute global y max across all response variables for shared axis
    global_max = 0
    for response in RESPONSE_VARS:
        plot_df = (
            df_fixed_tidy[df_fixed_tidy['response'] == response]
            .drop_duplicates(subset=['lag', 'pred_set'])
            [['lag', 'pred_set', 'aic', 'convergence_ok']]
            .copy()
        )
        min_aic = plot_df.groupby('lag')['aic'].min()
        plot_df['delta_aic'] = plot_df.apply(
            lambda row: row['aic'] - min_aic[row['lag']], axis=1
        )
        global_max = max(global_max, plot_df['delta_aic'].max())

    for ax, response in zip(axes, RESPONSE_VARS):

        plot_df = (
            df_fixed_tidy[df_fixed_tidy['response'] == response]
            .drop_duplicates(subset=['lag', 'pred_set'])
            [['lag', 'pred_set', 'aic', 'convergence_ok']]
            .copy()
        )

        lags = sorted(plot_df['lag'].unique())
        x    = np.arange(len(lags))

        min_aic = plot_df.groupby('lag')['aic'].min()
        plot_df['delta_aic'] = plot_df.apply(
            lambda row: row['aic'] - min_aic[row['lag']], axis=1
        )

        for i, pred_set in enumerate(PRED_ORDER):
            for j, lag in enumerate(lags):

                subset = plot_df[
                    (plot_df['pred_set'] == pred_set) & (plot_df['lag'] == lag)
                ]
                if subset.empty:
                    continue

                row       = subset.iloc[0]
                converged = bool(row['convergence_ok'])
                height    = float(row['delta_aic'])
                offset    = x[j] + OFFSETS[i]

                ax.bar(
                    offset,
                    height + 5,
                    bottom=-5,
                    width=BAR_WIDTH * 0.9,
                    color=PRED_COLORS[pred_set],
                    hatch='//' if not converged else None,
                    edgecolor='black' if not converged else 'white',
                    linewidth=0.5
                )

        ax.set_xticks(x)
        ax.set_xticklabels([f'{l}d' for l in lags])
        ax.set_xlabel('Lag window (days)')
        ax.set_ylabel('ΔAIC (from best model at each lag)')
        ax.set_title(response, fontweight='bold')
        ax.set_ylim(bottom=-5, top=global_max * 1.05)
        ax.axhline(0, color='black', linewidth=0.8, linestyle='--')
        ax.grid(axis='y', alpha=0.3)
        ax.spines[['top', 'right']].set_visible(False)

    handles = [Patch(facecolor=PRED_COLORS[p], label=p) for p in PRED_ORDER]
    handles += [Patch(facecolor='white', hatch='//', edgecolor='black', label='non-converged')]
    fig.legend(handles=handles, loc='lower center', ncol=4, fontsize=9,
               bbox_to_anchor=(0.5, -0.02))

    fig.suptitle('AIC comparison by predictor set and lag window\n(ΔAIC relative to best model at each lag)',
                 fontsize=12, fontweight='bold')

    plt.tight_layout()
    plt.savefig(os.path.join(plot_save_dir, 'RQ1_06_aic_comparison.png'),
                dpi=150, bbox_inches='tight')
    plt.show()

# %%
plot_aic(df_fixed_tidy, plot_dir)
# Out:
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\1745917325.py:89: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### 4.7 Biome Boxplot

# %%
def plot_biome_boxplot(df_random_tidy, df, response, lag, pred_set, plot_save_dir, biome_color_map):
    
    plot_df = df_random_tidy[
        (df_random_tidy['response'] == response) &
        (df_random_tidy['lag'] == lag) &
        (df_random_tidy['pred_set'] == pred_set) &
        (df_random_tidy['predictors'] == f'{pred_set}_anomaly_{lag}d')
    ]

    eco_meta = df[['eco_id', 'biome_name']].drop_duplicates()
    plot_df  = plot_df.merge(eco_meta, on='eco_id')

    # Sort biomes by median slope
    biome_order = plot_df.groupby('biome_name')['slope'].median().sort_values().index.tolist()

    fig, ax = plt.subplots(figsize=(10, 6))
    
    data_by_biome = [plot_df[plot_df['biome_name'] == b]['slope'].values for b in biome_order]
    bp = ax.boxplot(data_by_biome, vert=False, patch_artist=True, labels=biome_order)

    # Use consistent biome colors from global map
    for patch, biome in zip(bp['boxes'], biome_order):
        patch.set_facecolor(biome_color_map[biome])

    ax.set_xlabel('Per-ecoregion slope (days/°C)' if pred_set == 'temp' else 'Per-ecoregion slope (days/mm)')
    ax.set_title(f'{pred_set} sensitivity of {response} by biome ({lag}d lag)')
    plt.tight_layout()
    plt.savefig(os.path.join(plot_save_dir, f'RQ1_07_biome_boxplot_{response}_{pred_set}_{lag}d.png'),
                dpi=150, bbox_inches='tight')
    plt.show()

# %%
plot_biome_boxplot(df_random_tidy, df, "onset_doy", 90, 'temp',   plot_dir, BIOME_COLOR_MAP)
plot_biome_boxplot(df_random_tidy, df, "onset_doy", 90, 'precip', plot_dir, BIOME_COLOR_MAP)
# Out:
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\4207268258.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot(data_by_biome, vert=False, patch_artist=True, labels=biome_order)
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\4207268258.py:30: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\4207268258.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot(data_by_biome, vert=False, patch_artist=True, labels=biome_order)
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\4207268258.py:30: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### 4.8 Temp vs Precip Scatter

# %%
def plot_temp_precip_scatter(df_random_tidy, df, response, lag, plot_save_dir, biome_color_map):
    
    temp_df = df_random_tidy[
        (df_random_tidy['response'] == response) &
        (df_random_tidy['lag'] == lag) &
        (df_random_tidy['pred_set'] == 'temp') &
        (df_random_tidy['predictors'] == f'temp_anomaly_{lag}d')
    ][['eco_id', 'slope']].rename(columns={'slope': 'temp_slope'})

    precip_df = df_random_tidy[
        (df_random_tidy['response'] == response) &
        (df_random_tidy['lag'] == lag) &
        (df_random_tidy['pred_set'] == 'precip') &
        (df_random_tidy['predictors'] == f'precip_anomaly_{lag}d')
    ][['eco_id', 'slope']].rename(columns={'slope': 'precip_slope'})

    plot_df  = temp_df.merge(precip_df, on='eco_id')
    eco_meta = df[['eco_id', 'biome_name', 'eco_name']].drop_duplicates()
    plot_df  = plot_df.merge(eco_meta, on='eco_id')

    colors = [biome_color_map[b] for b in plot_df['biome_name']]

    fig, ax = plt.subplots(figsize=(9, 7))
    ax.scatter(plot_df['temp_slope'], plot_df['precip_slope'],
               c=colors, s=60, edgecolors='black', linewidth=0.5)
    ax.axhline(0, color='black', linewidth=0.8, linestyle='--')
    ax.axvline(0, color='black', linewidth=0.8, linestyle='--')
    ax.set_xlabel('Temperature slope (days/°C)')
    ax.set_ylabel('Precipitation slope (days/mm)')
    ax.set_title(f'Temp vs precip sensitivity per ecoregion — {response} ({lag}d lag)')

    legend_elements = [Patch(facecolor=biome_color_map[b], label=b) for b in biome_color_map]
    ax.legend(handles=legend_elements, fontsize=7)

    plt.tight_layout()
    plt.savefig(os.path.join(plot_save_dir, f'RQ1_08_temp_precip_scatter_{response}_{lag}d.png'),
                dpi=150, bbox_inches='tight')
    plt.show()

# %%
plot_temp_precip_scatter(df_random_tidy, df, 'onset_doy', 90, plot_dir, BIOME_COLOR_MAP)
# Out:
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\4027351335.py:38: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## 5: ROBUSTNESS CHECKS

# %%
# Primary specification
# All robustness checks below are run against this single spec.
# Change these values to re-run checks for a different response/lag/predictor.

PRIMARY_RESPONSE  = 'onset_doy'
PRIMARY_LAG       = 90
PRIMARY_PRED_SET  = 'temp'
PRIMARY_PREDICTOR = f'temp_anomaly_{PRIMARY_LAG}d'

# %%
# Filter df_random_tidy to the primary spec — one row per ecoregion
rob_df = df_random_tidy[
    (df_random_tidy['response']   == PRIMARY_RESPONSE) &
    (df_random_tidy['lag']        == PRIMARY_LAG) &
    (df_random_tidy['pred_set']   == PRIMARY_PRED_SET) &
    (df_random_tidy['predictors'] == PRIMARY_PREDICTOR)
].copy()

# Flag ecoregions whose slope is more than 2 SD from the mean.
# 2 SD captures ~95% of a normal distribution — anything outside is
# considered extreme enough to warrant scrutiny.
slope_mean = rob_df['slope'].mean()
slope_std  = rob_df['slope'].std()
rob_df['outlier_flag'] = (rob_df['slope'] - slope_mean).abs() > 2 * slope_std

print(f"Slope mean: {slope_mean:.2f} days/°C")
print(f"Slope std:  {slope_std:.2f} days/°C")
print(f"Outliers flagged: {rob_df['outlier_flag'].sum()} / {len(rob_df)} ecoregions")
print()
print(rob_df[rob_df['outlier_flag']][['eco_id', 'slope']])
# Out:
# Slope mean: -3.66 days/°C
# Slope std:  0.92 days/°C
# Outliers flagged: 31 / 706 ecoregions
#
#         eco_id     slope
# 209708      28 -5.572379
# 209742      70 -5.625855
# 209747      75 -5.709010
# 209754      83 -6.254234
# 209755      84 -5.924885
# 209785     136 -5.765300
# 209808     166 -5.740365
# 209826     188 -5.992655
# 209837     201 -6.050439
# 209877     245 -5.547720
# 209977     356 -5.721020
# 209986     365 -6.741763
# 209993     372 -5.525810
# 210022     406 -5.621880
# 210027     412 -5.575085
# 210028     413 -5.606487
# 210029     414 -5.573067
# 210051     444 -5.639350
# 210052     445 -6.013360
# 210072     469 -5.710688
# 210079     476 -5.865147
# 210083     480 -6.153974
# 210085     482 -5.581238
# 210100     497 -5.896163
# 210106     505 -5.801784
# 210116     518 -5.965744
# 210136     540 -5.648660
# 210305     752 -5.813069
# 210313     762 -6.176217
# 210324     775 -5.532188
# 210326     778 -5.539139

# %%
# For each ecoregion, compute Spearman ρ between temperature anomaly and onset DOY independently, 
# completely ignoring the mixed model. This is a model-free sanity check: if β and ρ agree in sign,
# the mixed model result is not an artefact.

spearman_rows = []

for eco_id, group in df.groupby('eco_id'):
    x = group[PRIMARY_PREDICTOR].dropna()
    y = group[PRIMARY_RESPONSE].dropna()

    common_idx = x.index.intersection(y.index)
    x = x.loc[common_idx]
    y = y.loc[common_idx]

    if len(x) < 5:
        continue

    rho, pval = spearmanr(x, y)
    spearman_rows.append({'eco_id': eco_id, 'spearman_rho': rho, 'spearman_pval': pval})

spearman_df = pd.DataFrame(spearman_rows)
print(f"Spearman correlations computed for {len(spearman_df)} ecoregions.")
# Out:
# Spearman correlations computed for 680 ecoregions.

# %%
# Shared ecoregion metadata — used throughout the robustness section
eco_meta = df[['eco_id', 'eco_name', 'biome_name']].drop_duplicates()

# Merge mixed model slopes and Spearman into one table
df_robust = (
    rob_df[['eco_id', 'slope', 'outlier_flag']]
    .merge(spearman_df, on='eco_id', how='inner')
    .merge(eco_meta,    on='eco_id', how='left')
)

# Sign agreement: do β and ρ point in the same direction?
df_robust['sign_agreement'] = (
    np.sign(df_robust['slope']) == np.sign(df_robust['spearman_rho'])
)

# Separate failure reasons explicitly
df_robust['fails_outlier']          = df_robust['outlier_flag']
df_robust['fails_sign_agreement']   = ~df_robust['sign_agreement']

# passes_all: must pass both checks
df_robust['passes_all'] = (
    ~df_robust['outlier_flag'] &
     df_robust['sign_agreement']
)

# Summary printout
print(df_robust[['eco_name', 'slope', 'spearman_rho',
                 'outlier_flag', 'sign_agreement', 'passes_all']].sort_values('slope').to_string())
print()
print(f"Ecoregions passing robustness checks: {df_robust['passes_all'].sum()} / {len(df_robust)}")
print(f"  - Fails outlier check only:         {(df_robust['fails_outlier'] & df_robust['sign_agreement']).sum()}")
print(f"  - Fails sign agreement only:        {(~df_robust['fails_outlier'] & df_robust['fails_sign_agreement']).sum()}")
print(f"  - Fails both:                       {(df_robust['fails_outlier'] & df_robust['fails_sign_agreement']).sum()}")


df_robust.to_csv(os.path.join(results_dir, 'rq1_robustness_summary.csv'), index=False)
print("\nSaved: rq1_robustness_summary.csv")
# Out:
#                                                               eco_name     slope  spearman_rho  outlier_flag  sign_agreement  passes_all
# 70                                         Madagascar ericoid thickets -6.254234     -0.023564          True            True       False
# 387                                                      Marajó várzea -6.153974     -0.452028          True            True       False
# 356                                    Caatinga Enclaves moist forests -6.013360     -0.076619          True            True       False
# 136                                   Trans Fly savanna and grasslands -5.992655     -0.247652          True            True       False
# 420                             Xingu-Tocantins-Araguaia moist forests -5.965744     -0.501978          True            True       False
# 71                                    Mulanje Montane forest-grassland -5.924885     -0.270622          True            True       False
# 404                                        Purus-Madeira moist forests -5.896163     -0.578874          True            True       False
# 383                                      Madeira-Tapajós moist forests -5.865147     -0.461882          True            True       False
# 410                                     Southwest Amazon moist forests -5.801784     -0.251731          True            True       False
# 96                           Banda Sea Islands moist deciduous forests -5.765300     -0.131520          True            True       False
# 118                                  Timor and Wetar deciduous forests -5.740365     -0.627936          True            True       False
# 285                                        Great Basin montane forests -5.721020     -0.447059          True            True       False
# 376                                                     Iquitos várzea -5.710688     -0.148515          True            True       False
# 63                                   Zambezian coastal flooded savanna -5.709010     -0.546713          True            True       False
# 440                                            Maranhão Babaçu forests -5.648660     -0.478358          True            True       False
# 355                                                    Bolivian Yungas -5.639350     -0.073671          True            True       False
# 58                                              Etosha Pan halophytics -5.625855      0.478361          True           False       False
# 333                                         Canadian Low Arctic tundra -5.606487      0.376901          True           False       False
# 389                                                Monte Alegre várzea -5.581238     -0.596587          True            True       False
# 332                                        Canadian High Arctic tundra -5.575085     -0.600000          True            True       False
# 334                                      Canadian Middle Arctic Tundra -5.573067     -0.289178          True            True       False
# 25                      Southern Swahili coastal forests and woodlands -5.572379     -0.182133          True            True       False
# 620                                  Northeast Siberian coastal tundra -5.532188     -0.189142          True            True       False
# 299                                               Copper Plateau taiga -5.525810      0.107143          True           False       False
# 419                                      Western Ecuador moist forests -5.465011     -0.508893         False            True        True
# 8                                                  Eastern Arc forests -5.444133     -0.416708         False            True        True
# 306                                     Northern Canadian Shield taiga -5.415822     -0.109791         False            True        True
# 308                                        Northwest Territories taiga -5.413301     -0.035603         False            True        True
# 337                      Pacific Coastal Mountain icefields and tundra -5.393194      0.523810         False           False       False
# 43                                           Kalahari Acacia woodlands -5.372483     -0.577503         False            True        True
# 331                                        Brooks-British Range tundra -5.371985      0.048739         False           False       False
# 278                           British Columbia coastal conifer forests -5.360293     -0.198220         False            True        True
# 425                                       Bolivian montane dry forests -5.358384     -0.278693         False            True        True
# 74                              Southern Rift Montane forest-grassland -5.356123      0.401682         False           False       False
# 330                                             Beringia upland tundra -5.350245     -0.166667         False            True        True
# 57                                            East African halophytics -5.346961      0.333333         False           False       False
# 328                                            Arctic foothills tundra -5.336573      0.128099         False           False       False
# 480                                            Central Andean wet puna -5.304037      0.172064         False           False       False
# 61                                            Makgadikgadi halophytics -5.298721     -0.102941         False            True        True
# 329                                            Beringia lowland tundra -5.288428     -0.194994         False            True        True
# 381                                          Juruá-Purus moist forests -5.262191     -0.002475         False            True        True
# 290                                               Okanogan dry forests -5.256045     -0.476520         False            True        True
# 38                                                Dry miombo woodlands -5.252632     -0.374197         False            True        True
# 296                                     Alaska Peninsula montane taiga -5.249151     -0.188811         False            True        True
# 301                                      Eastern Canadian Shield taiga -5.247392     -0.464852         False            True        True
# 294                                      South Central Rockies forests -5.244584     -0.170171         False            True        True
# 509                                          Fiji tropical dry forests -5.234718     -0.172022         False            True        True
# 92                                                Madagascar mangroves -5.234205      0.085085         False           False       False
# 287                                     North Cascades conifer forests -5.231827     -0.175482         False            True        True
# 336                                    Ogilvie-MacKenzie alpine tundra -5.228643     -0.323282         False            True        True
# 72                         Nyanga-Chimanimani Montane forest-grassland -5.226920      0.018784         False           False       False
# 298                                                   Cook Inlet taiga -5.224984     -0.428571         False            True        True
# 281                                  Central-Southern Cascades Forests -5.210276     -0.266996         False            True        True
# 131                               Cape York Peninsula tropical savanna -5.210134     -0.563659         False            True        True
# 432                                             Ecuadorian dry forests -5.207301     -0.282184         False            True        True
# 618                                    Cherskii-Kolyma mountain tundra -5.202397      0.255130         False           False       False
# 304                                    Midwest Canadian Shield forests -5.194288     -0.198220         False            True        True
# 409                                             Southern Andean Yungas -5.194210      0.388724         False           False       False
# 117                                            Sumba deciduous forests -5.190767      0.030168         False           False       False
# 326                                   Ahklun and Kilbuck Upland Tundra -5.187838      0.066667         False           False       False
# 622                                              Russian Bering tundra -5.178851      0.035065         False           False       False
# 412                                    Tocantins/Pindare moist forests -5.176772     -0.397328         False            True        True
# 297                                    Central Canadian Shield forests -5.168635     -0.408590         False            True        True
# 161                                               New Guinea mangroves -5.167850     -0.240610         False            True        True
# 573                                                    Kamchatka taiga -5.160467     -0.120588         False            True        True
# 108                       Southern New Guinea freshwater swamp forests -5.147277     -0.428466         False            True        True
# 624                                     Taimyr-Central Siberian tundra -5.145654     -0.280346         False            True        True
# 300                                           Eastern Canadian forests -5.142500      0.048527         False           False       False
# 3                                                      Comoros forests -5.139270     -0.157895         False            True        True
# 309                                             Watson Highlands taiga -5.134753     -0.220776         False            True        True
# 302                                Interior Alaska-Yukon lowland taiga -5.133508     -0.054456         False            True        True
# 54                                        Zambezian Baikiaea woodlands -5.126018     -0.568177         False            True        True
# 31                                            Angolan mopane woodlands -5.124314     -0.492087         False            True        True
# 335                                Interior Yukon-Alaska alpine tundra -5.118964      0.197280         False           False       False
# 460                                                       Beni savanna -5.093091      0.365438         False           False       False
# 30                                     Zambezian evergreen dry forests -5.089230     -0.332261         False            True        True
# 55                                          Zambezian mopane woodlands -5.087873     -0.614053         False            True        True
# 400                                                    Peruvian Yungas -5.075029      0.113226         False           False       False
# 42                                                 Itigi-Sumbu thicket -5.064675     -0.525717         False            True        True
# 56                                   Zambezian-Limpopo mixed woodlands -5.027632     -0.455984         False            True        True
# 567                            Mediterranean conifer and mixed forests -5.025155     -0.562176         False            True        True
# 481                                          Cordillera Central páramo -5.004133      0.010386         False           False       False
# 621                             Northwest Russian-Novaya Zemlya tundra -4.972612     -0.322118         False            True        True
# 626                                                 Yamal-Gydan tundra -4.965529     -0.286281         False            True        True
# 536                                          Madeira evergreen forests -4.960611     -0.015385         False            True        True
# 33                                        Angolan wet miombo woodlands -4.958738     -0.240141         False            True        True
# 575                                           Northeast Siberian taiga -4.956785      0.134981         False           False       False
# 157                                  Nullarbor Plains xeric shrublands -4.951053      0.341669         False           False       False
# 305                                            Muskwa-Slave Lake taiga -4.951028     -0.444225         False            True        True
# 16                                         Madagascar subhumid forests -4.937841      0.019307         False           False       False
# 15                                            Madagascar humid forests -4.922028     -0.168562         False            True        True
# 327                                      Alaska-St. Elias Range tundra -4.908765      0.177510         False           False       False
# 307                                        Northern Cordillera forests -4.903748      0.015819         False           False       False
# 619                                                   Kamchatka tundra -4.898678      0.058884         False           False       False
# 35                              Central Zambezian wet miombo woodlands -4.893807     -0.336467         False            True        True
# 479                                                Central Andean puna -4.880763      0.280702         False           False       False
# 65                                    Angolan montane forest-grassland -4.873262     -0.385436         False            True        True
# 292                                              Puget lowland forests -4.854746     -0.375278         False            True        True
# 289                                   Northern Rockies conifer forests -4.823971     -0.427794         False            True        True
# 64                                        Zambezian flooded grasslands -4.819382     -0.572631         False            True        True
# 115                                    Lesser Sundas deciduous forests -4.791072     -0.793667         False            True        True
# 648               Tyrrhenian-Adriatic sclerophyllous and mixed forests -4.781962     -0.105784         False            True        True
# 29                                    Madagascar dry deciduous forests -4.781882     -0.319129         False            True        True
# 279                          Central British Columbia Mountain forests -4.775529     -0.157687         False            True        True
# 277                                             Blue Mountains forests -4.739402     -0.110260         False            True        True
# 512                                    Hawai'i tropical low shrublands -4.720051      0.009112         False           False       False
# 461                                   Campos Rupestres montane savanna -4.716703     -0.130961         False            True        True
# 80                                              Kalahari xeric savanna -4.703733     -0.597627         False            True        True
# 344                                     Gulf of California xeric scrub -4.692238     -0.342405         False            True        True
# 382                                      Leeward Islands moist forests -4.682531     -0.414431         False            True        True
# 426                                     Brazilian Atlantic dry forests -4.679329     -0.246724         False            True        True
# 142                         Papuan Central Range sub-alpine grasslands -4.673485     -0.085714         False            True        True
# 32                                 Angolan scarp savanna and woodlands -4.666800      0.169140         False           False       False
# 625                                  Trans-Baikal Bald Mountain tundra -4.662988     -0.256740         False            True        True
# 129                                       Arnhem Land tropical savanna -4.655520     -0.459863         False            True        True
# 610                                 Qilian Mountains subalpine meadows -4.640358     -0.111588         False            True        True
# 577                                              Sakhalin Island taiga -4.611103      0.000495         False           False       False
# 293                                              Sierra Nevada forests -4.609950      0.193230         False           False       False
# 286                                           Klamath-Siskiyou forests -4.607830      0.285714         False           False       False
# 79                                             Eritrean coastal desert -4.606996     -0.098246         False            True        True
# 442                                           Patía valley dry forests -4.601379      0.332233         False           False       False
# 284                           Fraser Plateau and Basin conifer forests -4.593327     -0.258527         False            True        True
# 53                                    Western Congolian forest-savanna -4.566536     -0.042090         False            True        True
# 163                                        Borneo lowland rain forests -4.565130     -0.279783         False            True        True
# 629                           Canary Islands dry woodlands and forests -4.529877     -0.121983         False            True        True
# 506                                        Fiji tropical moist forests -4.527069      0.094737         False           False       False
# 632                                       Cyprus Mediterranean forests -4.506754     -0.411169         False            True        True
# 646           Southern Anatolian montane conifer and deciduous forests -4.505231      0.174988         False           False       False
# 82                                      Madagascar succulent woodlands -4.502504     -0.138511         False            True        True
# 576                                           Okhotsk-Manchurian taiga -4.495401      0.140490         False           False       False
# 51                                   Southern Congolian forest-savanna -4.488589      0.365264         False           False       False
# 112                                     Trobriand Islands rain forests -4.475313      0.012342         False           False       False
# 565                                   Hokkaido montane conifer forests -4.471492     -0.345295         False            True        True
# 81                                           Madagascar spiny thickets -4.470570     -0.461310         False            True        True
# 295                                  Wasatch and Uinta montane forests -4.443793     -0.248579         False            True        True
# 85                                          Namibian savanna woodlands -4.439039      0.028169         False           False       False
# 530                                Eastern Anatolian deciduous forests -4.436656     -0.237213         False            True        True
# 581                                                West Siberian taiga -4.425827     -0.161721         False            True        True
# 264                          Eastern Canadian Forest-Boreal transition -4.412580     -0.193868         False            True        True
# 475                                                           Pantanal -4.409302     -0.253027         False            True        True
# 18                                                   Mascarene forests -4.404632      0.175141         False           False       False
# 415                                              Ucayali moist forests -4.402878     -0.216016         False            True        True
# 325                                      Willamette Valley oak savanna -4.395848     -0.372220         False            True        True
# 462                                                            Cerrado -4.388743     -0.292852         False            True        True
# 28                                      Cape Verde Islands dry forests -4.385695     -0.100000         False            True        True
# 478                                            Central Andean dry puna -4.383168     -0.364220         False            True        True
# 132                                       Carpentaria tropical savanna -4.369502     -0.547614         False            True        True
# 633                    Eastern Mediterranean conifer-broadleaf forests -4.350756     -0.721552         False            True        True
# 574                        Kamchatka-Kurile meadows and sparse forests -4.348297      0.294805         False           False       False
# 303                                   Mid-Canada Boreal Plains forests -4.344223     -0.226621         False            True        True
# 603                                     Altai alpine meadow and tundra -4.323754     -0.191176         False            True        True
# 44                                                     Limpopo lowveld -4.314697     -0.177009         False            True        True
# 534                                         Hokkaido deciduous forests -4.308785     -0.255383         False            True        True
# 171                             Eastern Java-Bali montane rain forests -4.302535     -0.147270         False            True        True
# 109                           Southern New Guinea lowland rain forests -4.288758     -0.561898         False            True        True
# 665                                    Great Lakes Basin desert steppe -4.288233      0.160494         False           False       False
# 266                               Gulf of St. Lawrence lowland forests -4.270695     -0.548380         False            True        True
# 103                                         New Caledonia rain forests -4.243447     -0.288054         False            True        True
# 320                                         Northern Tallgrass prairie -4.237452     -0.571217         False            True        True
# 667                                                 Kazakh semi-desert -4.231908     -0.461768         False            True        True
# 102                       New Britain-New Ireland montane rain forests -4.226722     -0.401218         False            True        True
# 644                               South Apennine mixed montane forests -4.225838     -0.315451         False            True        True
# 209                          Southwest Borneo freshwater swamp forests -4.221786      0.000494         False           False       False
# 100                                Huon Peninsula montane rain forests -4.218854     -0.098863         False            True        True
# 311                               Canadian Aspen forests and parklands -4.203413     -0.542398         False            True        True
# 580                                     Urals montane forest and taiga -4.200725     -0.573268         False            True        True
# 554                                Western Siberian hemiboreal forests -4.193447     -0.540863         False            True        True
# 340                         California montane chaparral and woodlands -4.191196     -0.016807         False            True        True
# 631                                        Crete Mediterranean forests -4.186988     -0.083004         False            True        True
# 134                                          Kimberly tropical savanna -4.186227     -0.413248         False            True        True
# 557                             Altai montane forest and forest steppe -4.181811      0.144703         False           False       False
# 216                                            Sundaland heath forests -4.180664     -0.216951         False            True        True
# 341                          Santa Lucia Montane Chaparral & Woodlands -4.177693     -0.160653         False            True        True
# 591                                          Sayan Intermontane steppe -4.173304     -0.161641         False            True        True
# 97                                                   Buru rain forests -4.169159     -0.167532         False            True        True
# 354                                             Bahia interior forests -4.168143     -0.126175         False            True        True
# 17                            Maputaland coastal forests and woodlands -4.167848     -0.082077         False            True        True
# 593                                       South Siberian forest steppe -4.149975     -0.637309         False            True        True
# 578                                     Scandinavian and Russian taiga -4.137699     -0.518189         False            True        True
# 583                                       Altai steppe and semi-desert -4.135512     -0.277723         False            True        True
# 589                                               Kazakh upland steppe -4.128043     -0.330530         False            True        True
# 34                                                    Central bushveld -4.116471     -0.549543         False            True        True
# 239                                     Sumatran tropical pine forests -4.098522      0.300000         False           False       False
# 164                                          Borneo peat swamp forests -4.098362      0.003460         False           False       False
# 608                    Northwestern Himalayan alpine shrub and meadows -4.087634     -0.105590         False            True        True
# 282                                           Colorado Rockies forests -4.085306     -0.014332         False            True        True
# 374                                                      Gurupa várzea -4.081977      0.017297         False           False       False
# 84                                     Namaqualand-Richtersveld steppe -4.069131     -0.657143         False            True        True
# 274                                        Western Great Lakes forests -4.064387     -0.489736         False            True        True
# 37                                              Drakensberg grasslands -4.060151     -0.190311         False            True        True
# 539                                 Nihonkai montane deciduous forests -4.059867     -0.621849         False            True        True
# 269                                        New England-Acadian forests -4.047487     -0.300198         False            True        True
# 283                                           Eastern Cascades forests -4.041302     -0.410878         False            True        True
# 521                             Central Anatolian steppe and woodlands -4.031567     -0.231225         False            True        True
# 569                   Northern Anatolian conifer and deciduous forests -4.015240     -0.209901         False            True        True
# 347                                        Snake-Columbia shrub steppe -4.012743     -0.210084         False            True        True
# 107                                      Southeast Papuan rain forests -4.012095      0.080059         False           False       False
# 259                                        Allegheny Highlands forests -4.003917     -0.578635         False            True        True
# 352                                            Araucaria moist forests -3.991269     -0.143810         False            True        True
# 637                  Italian sclerophyllous and semi-deciduous forests -3.971734     -0.161641         False            True        True
# 547                                             Sarmatic mixed forests -3.959427     -0.696041         False            True        True
# 630                       Corsican montane broadleaf and mixed forests -3.957820     -0.078571         False            True        True
# 538                                         Nihonkai evergreen forests -3.951719     -0.449172         False            True        True
# 587                                                 Emin Valley steppe -3.945156     -0.239585         False            True        True
# 41                                      Horn of Africa xeric bushlands -3.941612      0.600000         False           False       False
# 36                          Drakensberg Escarpment savanna and thicket -3.939143     -0.124073         False            True        True
# 392                                         Northeast Brazil restingas -3.935411     -0.241465         False            True        True
# 473                                       Guayaquil flooded grasslands -3.933955     -0.138374         False            True        True
# 156                                              Great Victoria desert -3.927897     -0.107293         False            True        True
# 172                                     Eastern Java-Bali rain forests -3.923732     -0.423913         False            True        True
# 83                                               Nama Karoo shrublands -3.918366     -0.557726         False            True        True
# 596                                                 Amur meadow steppe -3.917320     -0.434654         False            True        True
# 611                                    Sayan alpine meadows and tundra -3.912222     -0.222538         False            True        True
# 362                                            Chiapas montane forests -3.905799      0.214944         False           False       False
# 572                                  Tian Shan montane conifer forests -3.899964     -0.305791         False            True        True
# 529                                        East European forest steppe -3.898779     -0.622124         False            True        True
# 265                                Eastern Great Lakes lowland forests -3.898195     -0.647874         False            True        True
# 388                                   Mato Grosso tropical dry forests -3.884605     -0.461196         False            True        True
# 614                               Tian Shan montane steppe and meadows -3.884490     -0.094555         False            True        True
# 560                       Da Hinggan-Dzhagdy Mountains conifer forests -3.879670     -0.610782         False            True        True
# 592                                       Selenge-Orkhon forest steppe -3.873745     -0.351894         False            True        True
# 101                       New Britain-New Ireland lowland rain forests -3.870071     -0.050282         False            True        True
# 571                               Scandinavian coastal conifer forests -3.867522     -0.392698         False            True        True
# 319                                        Northern Shortgrass prairie -3.864223     -0.402572         False            True        True
# 104      Northern New Guinea lowland rain and freshwater swamp forests -3.859581     -0.153238         False            True        True
# 623                   Scandinavian Montane Birch forest and grasslands -3.853646     -0.434066         False            True        True
# 235                           Sri Lanka dry-zone dry evergreen forests -3.836581     -0.423628         False            True        True
# 647   Southwest Iberian Mediterranean sclerophyllous and mixed forests -3.834843      0.126482         False           False       False
# 203                                 Red River freshwater swamp forests -3.834252      0.149633         False           False       False
# 636                                         Illyrian deciduous forests -3.826473      0.188334         False           False       False
# 579                                       Trans-Baikal conifer forests -3.825163     -0.154341         False            True        True
# 600                          Suiphun-Khanka meadows and forest meadows -3.824468     -0.290451         False            True        True
# 273                         Upper Midwest US forest-savanna transition -3.818237     -0.502352         False            True        True
# 585                                              Daurian forest steppe -3.801544     -0.398713         False            True        True
# 98                           Central Range Papuan montane rain forests -3.799628      0.247097         False           False       False
# 280                          Central Pacific Northwest coastal forests -3.798488     -0.115175         False            True        True
# 643                                     Pindus Mountains mixed forests -3.786210     -0.316362         False            True        True
# 516                                               Baltic mixed forests -3.784529     -0.162296         False            True        True
# 496                                              San Lucan xeric scrub -3.782811     -0.400000         False            True        True
# 657                           Central Afghan Mountains xeric woodlands -3.781246     -0.327473         False            True        True
# 666                                          Junggar Basin semi-desert -3.762885      0.249753         False           False       False
# 584                                           Central Anatolian steppe -3.760672     -0.075099         False            True        True
# 350                                         Wyoming Basin shrub steppe -3.759997     -0.141409         False            True        True
# 224                                          Western Java rain forests -3.756543     -0.714427         False            True        True
# 537                                           Manchurian mixed forests -3.750899     -0.333830         False            True        True
# 360                            Central American Atlantic moist forests -3.747481     -0.269776         False            True        True
# 595                                     Tian Shan foothill arid steppe -3.743068     -0.299209         False            True        True
# 338                              California coastal sage and chaparral -3.735729     -0.285714         False            True        True
# 369                            Eastern Cordillera Real montane forests -3.728309      0.028656         False           False       False
# 256                            Sonoran-Sinaloan subtropical dry forest -3.720331      0.201631         False           False       False
# 421                                              Yucatán moist forests -3.715094     -0.336712         False            True        True
# 386                                                Marañón dry forests -3.712165     -0.166584         False            True        True
# 133                                          Einasleigh upland savanna -3.710962     -0.112265         False            True        True
# 531                                     English Lowlands beech forests -3.707015      0.166172         False           False       False
# 540                                 North Atlantic moist mixed forests -3.703637      0.228684         False           False       False
# 124                                         Richmond temperate forests -3.703187     -0.166937         False            True        True
# 86                          Southwest Arabian coastal xeric shrublands -3.698128     -0.355907         False            True        True
# 213                                  Sumatran freshwater swamp forests -3.696116      0.189770         False           False       False
# 317                                      Flint Hills tallgrass prairie -3.684270     -0.251057         False            True        True
# 288                                Northern California coastal forests -3.683971     -0.144906         False            True        True
# 673                                           Qaidam Basin semi-desert -3.682021      0.183824         False           False       False
# 640                                Mediterranean woodlands and forests -3.681838     -0.243143         False            True        True
# 394                                            Oaxacan montane forests -3.680330      0.128186         False           False       False
# 523                                     Central European mixed forests -3.679711     -0.424438         False            True        True
# 363                                         Chimalapas montane forests -3.672791     -0.067822         False            True        True
# 257                           Sierra Madre Occidental pine-oak forests -3.671686     -0.059377         False            True        True
# 562                                         Elburz Range forest steppe -3.671060      0.251544         False           False       False
# 514                                 Appenine deciduous montane forests -3.667871     -0.160440         False            True        True
# 14                                  Kwazulu Natal-Cape coastal forests -3.667437      0.175074         False           False       False
# 628                      Anatolian conifer and deciduous mixed forests -3.658354     -0.319486         False            True        True
# 272                                       Southern Great Lakes forests -3.649109     -0.774481         False            True        True
# 518                                    Caspian Hyrcanian mixed forests -3.647874      0.177910         False           False       False
# 154                                                      Gibson desert -3.642754     -0.461082         False            True        True
# 321                                                    Palouse prairie -3.639148     -0.552721         False            True        True
# 658                                      Central Asian northern desert -3.635973     -0.772279         False            True        True
# 455                              Sierra Madre del Sur pine-oak forests -3.633415     -0.204849         False            True        True
# 491                                      Galápagos Islands xeric scrub -3.623237     -0.050037         False            True        True
# 664                                         Eastern Gobi desert steppe -3.610442     -0.192848         False            True        True
# 114                                      Vogelkop montane rain forests -3.608802     -0.244297         False            True        True
# 106                                                 Seram rain forests -3.607388     -0.569492         False            True        True
# 111                                      Sulawesi montane rain forests -3.603317     -0.225846         False            True        True
# 515                                               Balkan mixed forests -3.600569     -0.342970         False            True        True
# 627         Aegean and Western Turkey sclerophyllous and mixed forests -3.599698     -0.092931         False            True        True
# 602                                           Yellow Sea saline meadow -3.595364     -0.364629         False            True        True
# 449                                                Yucatán dry forests -3.593454     -0.438892         False            True        True
# 105                           Northern New Guinea montane rain forests -3.585020     -0.223776         False            True        True
# 454                            Sierra Madre de Oaxaca pine-oak forests -3.573315     -0.098937         False            True        True
# 137                                   Victoria Plains tropical savanna -3.564071     -0.803360         False            True        True
# 598                                           Nenjiang River grassland -3.562213     -0.352301         False            True        True
# 146                                   Flinders-Lofty montane woodlands -3.561387     -0.068266         False            True        True
# 542                                            Pannonian mixed forests -3.561268     -0.553276         False            True        True
# 141                        New Zealand South Island montane grasslands -3.551084     -0.250618         False            True        True
# 275                                          Arizona Mountains forests -3.537017     -0.094909         False            True        True
# 434                                                Jalisco dry forests -3.536185     -0.136038         False            True        True
# 214                                      Sumatran lowland rain forests -3.534041     -0.228430         False            True        True
# 427                                                           Caatinga -3.530826     -0.013834         False            True        True
# 590                                     Mongolian-Manchurian grassland -3.526622     -0.458263         False            True        True
# 532                                    European Atlantic mixed forests -3.525203     -0.240595         False            True        True
# 604                              Central Tibetan Plateau alpine steppe -3.511613      0.240475         False           False       False
# 659                                   Central Asian riparian woodlands -3.500583     -0.513397         False            True        True
# 149                                               Naracoorte woodlands -3.495494      0.150309         False           False       False
# 93                                                   Red Sea mangroves -3.487302      0.151948         False           False       False
# 566                                      Honshu alpine conifer forests -3.483473     -0.139860         False            True        True
# 483                                                         High Monte -3.478029     -0.545455         False            True        True
# 474                                                   Orinoco wetlands -3.477624     -0.600791         False            True        True
# 370                                 Eastern Panamanian montane forests -3.472009      0.179983         False           False       False
# 543                                             Po Basin mixed forests -3.469983     -0.163196         False            True        True
# 140                                 Australian Alps montane grasslands -3.461152      0.119597         False           False       False
# 656                                             Caspian lowland desert -3.458069     -0.269575         False            True        True
# 642                                  Northwest Iberian montane forests -3.455491     -0.147306         False            True        True
# 312                            Central US forest-grasslands transition -3.442855     -0.759219         False            True        True
# 553                                 Western European broadleaf forests -3.435080     -0.381612         False            True        True
# 94                                           Southern Africa mangroves -3.434046     -0.005933         False            True        True
# 145                                               Eyre and York mallee -3.433374      0.047053         False           False       False
# 588                                        Gissaro-Alai open woodlands -3.432111      0.019283         False           False       False
# 494                                          Motagua Valley thornscrub -3.431704     -0.271379         False            True        True
# 586                                   Eastern Anatolian montane steppe -3.430294     -0.070280         False            True        True
# 162                                       Andaman Islands rain forests -3.428924      0.200000         False           False       False
# 406                                              Sierra de los Tuxtlas -3.414851     -0.248208         False            True        True
# 459                                             Belizian pine savannas -3.413416     -0.329872         False            True        True
# 116                                          New Caledonia dry forests -3.410646     -0.440326         False            True        True
# 558                                            Caledon conifer forests -3.409386     -0.165018         False            True        True
# 155                                          Great Sandy-Tanami desert -3.407908     -0.786261         False            True        True
# 0                                       Albertine Rift montane forests -3.406391     -0.002472         False            True        True
# 395                                        Orinoco Delta swamp forests -3.404272     -0.354193         False            True        True
# 318                               Nebraska Sand Hills mixed grasslands -3.403445     -0.277966         False            True        True
# 180                      Lower Gangetic Plains moist deciduous forests -3.399879     -0.346192         False            True        True
# 634                                            Iberian conifer forests -3.398331      0.139140         False           False       False
# 258                             Sierra Madre Oriental pine-oak forests -3.397960      0.388628         False           False       False
# 199                                               Palawan rain forests -3.394614     -0.226080         False            True        True
# 211                                     Sri Lanka montane rain forests -3.394178     -0.327078         False            True        True
# 559                                         Carpathian montane forests -3.389578     -0.574679         False            True        True
# 351                                       Alto Paraná Atlantic forests -3.386909     -0.232271         False            True        True
# 401                                       Petén-Veracruz moist forests -3.385367     -0.488384         False            True        True
# 535                                       Huang He Plain mixed forests -3.385351     -0.346278         False            True        True
# 175                            Himalayan subtropical broadleaf forests -3.381309     -0.239862         False            True        True
# 150                                        Southwest Australia savanna -3.381214     -0.189463         False            True        True
# 377                                    Isthmian-Atlantic moist forests -3.379313     -0.029681         False            True        True
# 313                                          Central Tallgrass prairie -3.377690     -0.739789         False            True        True
# 520                                           Celtic broadleaf forests -3.369572     -0.232938         False            True        True
# 517                                           Cantabrian mixed forests -3.368948     -0.349567         False            True        True
# 524                                   Central Korean deciduous forests -3.368889     -0.145545         False            True        True
# 260                               Appalachian mixed mesophytic forests -3.366115      0.116803         False           False       False
# 528                                    Dinaric Mountains mixed forests -3.362424     -0.585125         False            True        True
# 276                                      Atlantic coastal pine barrens -3.358205     -0.564358         False            True        True
# 487                                        Araya and Paria xeric scrub -3.351247     -0.322373         False            True        True
# 548                          Sichuan Basin evergreen broadleaf forests -3.347858      0.104795         False           False       False
# 556                                     Alps conifer and mixed forests -3.346108     -0.511641         False            True        True
# 13                                      Knysna-Amatole montane forests -3.345915     -0.248208         False            True        True
# ...
# 227                                Chhota-Nagpur dry deciduous forests -2.785157      0.237683         False           False       False
# 143                                               Coolgardie woodlands -2.785155     -0.498269         False            True        True
# 353                                              Bahia coastal forests -2.784966     -0.600347         False            True        True
# 173                                  Greater Negros-Panay rain forests -2.783929     -0.156475         False            True        True
# 183                                                 Luzon rain forests -2.771225      0.091047         False           False       False
# 379                                             Jamaican moist forests -2.770239      0.212377         False           False       False
# 433                                            Hispaniolan dry forests -2.767642      0.160317         False           False       False
# 435                                               Jamaican dry forests -2.760188      0.008420         False           False       False
# 561                                East Afghan montane conifer forests -2.756882      0.257143         False           False       False
# 366                                Cordillera Oriental montane forests -2.756839     -0.291585         False            True        True
# 390                                                 Napo moist forests -2.755467     -0.524623         False            True        True
# 244                        Western Himalayan subalpine conifer forests -2.751367     -0.118494         False            True        True
# 405                                        Santa Marta montane forests -2.750109      0.050458         False           False       False
# 198                                      Orissa semi-evergreen forests -2.749343     -0.145895         False            True        True
# 357                                              Caqueta moist forests -2.748475     -0.456890         False            True        True
# 422                                    Apure-Villavicencio dry forests -2.745496     -0.252852         False            True        True
# 207                           South Western Ghats montane rain forests -2.744739     -0.252720         False            True        True
# 152                                         Carnarvon xeric shrublands -2.744622     -0.241780         False            True        True
# 663                               East Saharan montane xeric woodlands -2.742885      0.311865         False           False       False
# 675                                  Red Sea-Arabian Desert shrublands -2.742529      0.424258         False           False       False
# 322                                      Southeast US conifer savannas -2.741258     -0.026251         False            True        True
# 486                                                   Chilean Matorral -2.741035     -0.098491         False            True        True
# 372                                    Guianan Highlands moist forests -2.740118     -0.649160         False            True        True
# 192                           North Western Ghats montane rain forests -2.739734     -0.207426         False            True        True
# 242                                Western Himalayan broadleaf forests -2.736721     -0.137658         False            True        True
# 316                                            Edwards Plateau savanna -2.736615      0.247833         False           False       False
# 470                                                          Low Monte -2.736315     -0.508776         False            True        True
# 375                                          Hispaniolan moist forests -2.735202     -0.230275         False            True        True
# 27                                     Western Guinean lowland forests -2.733028     -0.289541         False            True        True
# 652                          Arabian-Persian Gulf coastal plain desert -2.730903     -0.085686         False            True        True
# 348                                                Tamaulipan matorral -2.728637     -0.371472         False            True        True
# 498                                           Tehuacán Valley matorral -2.727160      0.529078         False           False       False
# 263                                         East Central Texas forests -2.726608      0.046028         False           False       False
# 238                               Northeast India-Myanmar pine forests -2.725972     -0.202870         False            True        True
# 650                                                     Arabian desert -2.724836     -0.121722         False            True        True
# 601                               Tigris-Euphrates alluvial salt marsh -2.724226     -0.277202         False            True        True
# 431                                                  Cuban dry forests -2.723531     -0.285999         False            True        True
# 252                                                Indochina mangroves -2.722872     -0.241645         False            True        True
# 229                                              Irrawaddy dry forests -2.716776     -0.600400         False            True        True
# 458                                        Valdivian temperate forests -2.712817     -0.396437         False            True        True
# 349                                               Tamaulipan mezquital -2.704015     -0.174561         False            True        True
# 188                                               Mindoro rain forests -2.695794      0.374321         False           False       False
# 495                                              Paraguaná xeric scrub -2.691827      0.112516         False           False       False
# 428                                           Cauca Valley dry forests -2.687341     -0.350027         False            True        True
# 113                                               Vanuatu rain forests -2.687173      0.027762         False           False       False
# 323                                           Texas blackland prairies -2.686074      0.092148         False           False       False
# 397                                      Pantepui forests & shrublands -2.682020     -0.399308         False            True        True
# 504                              Southern Atlantic Brazilian mangroves -2.680207     -0.514357         False            True        True
# 232                         South Deccan Plateau dry deciduous forests -2.674900      0.032681         False           False       False
# 176                                 Irrawaddy freshwater swamp forests -2.674825     -0.634364         False            True        True
# 655                                        Baluchistan xeric woodlands -2.674031     -0.050570         False            True        True
# 178                             Jian Nan subtropical evergreen forests -2.673893     -0.477627         False            True        True
# 484                                             Northern Andean páramo -2.670655     -0.007923         False            True        True
# 505                            Southern Mesoamerican Pacific mangroves -2.668881     -0.105029         False            True        True
# 204                  South China-Vietnam subtropical evergreen forests -2.665113     -0.062361         False            True        True
# 221                                Tonle Sap-Mekong peat swamp forests -2.662872     -0.419464         False            True        True
# 123                                  Northland temperate kauri forests -2.661175     -0.161229         False            True        True
# 194                    Northern Khorat Plateau moist deciduous forests -2.660708      0.325743         False           False       False
# 67                          Ethiopian montane grasslands and woodlands -2.657554      0.019345         False           False       False
# 464                                                    Guianan savanna -2.657405     -0.557013         False            True        True
# 493                                          La Costa xeric shrublands -2.656719     -0.323415         False            True        True
# 76                                                    Fynbos shrubland -2.651346     -0.049144         False            True        True
# 429                                       Central American dry forests -2.650909      0.000000         False           False       False
# 253                            Indus River Delta-Arabian Sea mangroves -2.650861      0.175597         False           False       False
# 342                                           Central Mexican matorral -2.647048     -0.051003         False            True        True
# 50                     Somali Acacia-Commiphora bushlands and thickets -2.630642     -0.123268         False            True        True
# 513                       Yunnan Plateau subtropical evergreen forests -2.623182     -0.168359         False            True        True
# 446                                     Trinidad and Tobago dry forest -2.622434     -0.428571         False            True        True
# 343                                                  Chihuahuan desert -2.618058     -0.347848         False            True        True
# 391                                         Negro-Branco moist forests -2.617609     -0.432567         False            True        True
# 233                          Southeast Indochina dry evergreen forests -2.615923     -0.037324         False            True        True
# 191                        North Western Ghats moist deciduous forests -2.608418     -0.233722         False            True        True
# 472                                      Everglades flooded grasslands -2.603777      0.279896         False           False       False
# 423                                                  Bajío dry forests -2.603285     -0.280043         False            True        True
# 469                                                       Humid Pampas -2.602940     -0.262037         False            True        True
# 240                                Eastern Himalayan broadleaf forests -2.591602     -0.012871         False            True        True
# 345                                            Meseta Central matorral -2.590968     -0.046028         False            True        True
# 248                                         Deccan thorn scrub forests -2.589747     -0.374110         False            True        True
# 564                       Hengduan Mountains subalpine conifer forests -2.578283     -0.262077         False            True        True
# 399                                        Pernambuco interior forests -2.575212      0.070472         False           False       False
# 165                          Brahmaputra Valley semi-evergreen forests -2.569525     -0.264816         False            True        True
# 437                                       Lesser Antillean dry forests -2.568008      0.051299         False           False       False
# 168                        Chao Phraya lowland moist deciduous forests -2.562690     -0.041181         False            True        True
# 184                                        Malabar Coast moist forests -2.558251      0.004461         False           False       False
# 407                              Sierra Madre de Chiapas moist forests -2.556033      0.008960         False           False       False
# 605                         Eastern Himalayan alpine shrub and meadows -2.552730     -0.252664         False            True        True
# 19                            Mount Cameroon and Bioko montane forests -2.549544     -0.331446         False            True        True
# 47                   Northern Acacia-Commiphora bushlands and thickets -2.548775     -0.522480         False            True        True
# 166                                    Cardamom Mountains rain forests -2.541867     -0.214394         False            True        True
# 7                                         East African montane forests -2.540504     -0.375686         False            True        True
# 89                                           Central African mangroves -2.540172      0.005975         False           False       False
# 24                                 Northwest Congolian lowland forests -2.536418      0.006478         False           False       False
# 243                        Eastern Himalayan subalpine conifer forests -2.536398     -0.177900         False            True        True
# 49                                             Sahelian Acacia savanna -2.534380     -0.052096         False            True        True
# 6                                   Cross-Sanaga-Bioko coastal forests -2.532682      0.266703         False           False       False
# 167                               Chao Phraya freshwater swamp forests -2.530355      0.198116         False           False       False
# 466                                                             Llanos -2.527791     -0.554659         False            True        True
# 21                                            Nigerian lowland forests -2.522091      0.206815         False           False       False
# 10                                             Eastern Guinean forests -2.516814     -0.208726         False            True        True
# 45                                           Mandara Plateau woodlands -2.512960     -0.344334         False            True        True
# 226                                      Central Indochina dry forests -2.508963     -0.307822         False            True        True
# 398                                         Pernambuco coastal forests -2.507923     -0.061554         False            True        True
# 22                                 Northeast Congolian lowland forests -2.506639     -0.048696         False            True        True
# 241                                Northern Triangle temperate forests -2.506062     -0.081758         False            True        True
# 20                                           Niger Delta swamp forests -2.498329     -0.156932         False            True        True
# 5                                       Cross-Niger transition forests -2.495267      0.103801         False           False       False
# 12                                             Guinean montane forests -2.489252     -0.130646         False            True        True
# 11                                           Ethiopian montane forests -2.478362     -0.296822         False            True        True
# 52                                               West Sudanian savanna -2.464285     -0.065227         False            True        True
# 69                                        Jos Plateau forest-grassland -2.460737     -0.250012         False            True        True
# 39                                               East Sudanian savanna -2.454902     -0.045099         False            True        True
# 62                                             Sudd flooded grasslands -2.454637     -0.128235         False            True        True
# 1                                           Cameroon Highlands forests -2.452133      0.101835         False           False       False
# 48                                   Northern Congolian Forest-Savanna -2.445844      0.171055         False           False       False
# 40                                              Guinean forest-savanna -2.443372      0.095786         False           False       False
#
# Ecoregions passing robustness checks: 485 / 680
#   - Fails outlier check only:         21
#   - Fails sign agreement only:        171
#   - Fails both:                       3
#
# Saved: rq1_robustness_summary.csv

# %%
# Group 1: Outlier flag
# These ecoregions have extreme slopes but sign agreement is intact.
# The mixed model may be overreaching in data-sparse ecoregions.
outlier_failures = df_robust[df_robust['fails_outlier']]

print(f"Group 1 — Outlier flag ({len(outlier_failures)} ecoregions):")
print("Both methods agree on direction but slope is numerically extreme.\n")
print(outlier_failures[['eco_name', 'biome_name', 'slope', 'spearman_rho']].sort_values('slope').to_string())
# Out:
# Group 1 — Outlier flag (24 ecoregions):
# Both methods agree on direction but slope is numerically extreme.
#
#                                            eco_name                                                biome_name     slope  spearman_rho
# 70                      Madagascar ericoid thickets                           Montane Grasslands & Shrublands -6.254234     -0.023564
# 387                                   Marajó várzea            Tropical & Subtropical Moist Broadleaf Forests -6.153974     -0.452028
# 356                 Caatinga Enclaves moist forests            Tropical & Subtropical Moist Broadleaf Forests -6.013360     -0.076619
# 136                Trans Fly savanna and grasslands  Tropical & Subtropical Grasslands, Savannas & Shrublands -5.992655     -0.247652
# 420          Xingu-Tocantins-Araguaia moist forests            Tropical & Subtropical Moist Broadleaf Forests -5.965744     -0.501978
# 71                 Mulanje Montane forest-grassland                           Montane Grasslands & Shrublands -5.924885     -0.270622
# 404                     Purus-Madeira moist forests            Tropical & Subtropical Moist Broadleaf Forests -5.896163     -0.578874
# 383                   Madeira-Tapajós moist forests            Tropical & Subtropical Moist Broadleaf Forests -5.865147     -0.461882
# 410                  Southwest Amazon moist forests            Tropical & Subtropical Moist Broadleaf Forests -5.801784     -0.251731
# 96        Banda Sea Islands moist deciduous forests            Tropical & Subtropical Moist Broadleaf Forests -5.765300     -0.131520
# 118               Timor and Wetar deciduous forests              Tropical & Subtropical Dry Broadleaf Forests -5.740365     -0.627936
# 285                     Great Basin montane forests                                 Temperate Conifer Forests -5.721020     -0.447059
# 376                                  Iquitos várzea            Tropical & Subtropical Moist Broadleaf Forests -5.710688     -0.148515
# 63                Zambezian coastal flooded savanna                             Flooded Grasslands & Savannas -5.709010     -0.546713
# 440                         Maranhão Babaçu forests              Tropical & Subtropical Dry Broadleaf Forests -5.648660     -0.478358
# 355                                 Bolivian Yungas            Tropical & Subtropical Moist Broadleaf Forests -5.639350     -0.073671
# 58                           Etosha Pan halophytics                             Flooded Grasslands & Savannas -5.625855      0.478361
# 333                      Canadian Low Arctic tundra                                                    Tundra -5.606487      0.376901
# 389                             Monte Alegre várzea            Tropical & Subtropical Moist Broadleaf Forests -5.581238     -0.596587
# 332                     Canadian High Arctic tundra                                                    Tundra -5.575085     -0.600000
# 334                   Canadian Middle Arctic Tundra                                                    Tundra -5.573067     -0.289178
# 25   Southern Swahili coastal forests and woodlands            Tropical & Subtropical Moist Broadleaf Forests -5.572379     -0.182133
# 620               Northeast Siberian coastal tundra                                                    Tundra -5.532188     -0.189142
# 299                            Copper Plateau taiga                                      Boreal Forests/Taiga -5.525810      0.107143

# %%
# Group 2: Sign disagreement 
# These ecoregions have β and ρ pointing in opposite directions.
# Likely candidates: desert/marginal ecoregions where fire timing
# is unreliable or temperature is not the primary driver.
sign_failures = df_robust[df_robust['fails_sign_agreement'] & ~df_robust['fails_outlier']]

print(f"Group 2 — Sign disagreement ({len(sign_failures)} ecoregions):")
print("Mixed model β and Spearman ρ point in opposite directions.\n")
print(sign_failures[['eco_name', 'biome_name', 'slope', 'spearman_rho']].sort_values('slope').to_string())
# Out:
# Group 2 — Sign disagreement (171 ecoregions):
# Mixed model β and Spearman ρ point in opposite directions.
#
#                                                               eco_name                                                biome_name     slope  spearman_rho
# 337                      Pacific Coastal Mountain icefields and tundra                                                    Tundra -5.393194      0.523810
# 331                                        Brooks-British Range tundra                                                    Tundra -5.371985      0.048739
# 74                              Southern Rift Montane forest-grassland                           Montane Grasslands & Shrublands -5.356123      0.401682
# 57                                            East African halophytics                             Flooded Grasslands & Savannas -5.346961      0.333333
# 328                                            Arctic foothills tundra                                                    Tundra -5.336573      0.128099
# 480                                            Central Andean wet puna                           Montane Grasslands & Shrublands -5.304037      0.172064
# 92                                                Madagascar mangroves                                                 Mangroves -5.234205      0.085085
# 72                         Nyanga-Chimanimani Montane forest-grassland                           Montane Grasslands & Shrublands -5.226920      0.018784
# 618                                    Cherskii-Kolyma mountain tundra                                                    Tundra -5.202397      0.255130
# 409                                             Southern Andean Yungas            Tropical & Subtropical Moist Broadleaf Forests -5.194210      0.388724
# 117                                            Sumba deciduous forests              Tropical & Subtropical Dry Broadleaf Forests -5.190767      0.030168
# 326                                   Ahklun and Kilbuck Upland Tundra                                                    Tundra -5.187838      0.066667
# 622                                              Russian Bering tundra                                                    Tundra -5.178851      0.035065
# 300                                           Eastern Canadian forests                                      Boreal Forests/Taiga -5.142500      0.048527
# 335                                Interior Yukon-Alaska alpine tundra                                                    Tundra -5.118964      0.197280
# 460                                                       Beni savanna  Tropical & Subtropical Grasslands, Savannas & Shrublands -5.093091      0.365438
# 400                                                    Peruvian Yungas            Tropical & Subtropical Moist Broadleaf Forests -5.075029      0.113226
# 481                                          Cordillera Central páramo                           Montane Grasslands & Shrublands -5.004133      0.010386
# 575                                           Northeast Siberian taiga                                      Boreal Forests/Taiga -4.956785      0.134981
# 157                                  Nullarbor Plains xeric shrublands                                Deserts & Xeric Shrublands -4.951053      0.341669
# 16                                         Madagascar subhumid forests            Tropical & Subtropical Moist Broadleaf Forests -4.937841      0.019307
# 327                                      Alaska-St. Elias Range tundra                                                    Tundra -4.908765      0.177510
# 307                                        Northern Cordillera forests                                      Boreal Forests/Taiga -4.903748      0.015819
# 619                                                   Kamchatka tundra                                                    Tundra -4.898678      0.058884
# 479                                                Central Andean puna                           Montane Grasslands & Shrublands -4.880763      0.280702
# 512                                    Hawai'i tropical low shrublands  Tropical & Subtropical Grasslands, Savannas & Shrublands -4.720051      0.009112
# 32                                 Angolan scarp savanna and woodlands  Tropical & Subtropical Grasslands, Savannas & Shrublands -4.666800      0.169140
# 577                                              Sakhalin Island taiga                                      Boreal Forests/Taiga -4.611103      0.000495
# 293                                              Sierra Nevada forests                                 Temperate Conifer Forests -4.609950      0.193230
# 286                                           Klamath-Siskiyou forests                                 Temperate Conifer Forests -4.607830      0.285714
# 442                                           Patía valley dry forests              Tropical & Subtropical Dry Broadleaf Forests -4.601379      0.332233
# 506                                        Fiji tropical moist forests            Tropical & Subtropical Moist Broadleaf Forests -4.527069      0.094737
# 646           Southern Anatolian montane conifer and deciduous forests                  Mediterranean Forests, Woodlands & Scrub -4.505231      0.174988
# 576                                           Okhotsk-Manchurian taiga                                      Boreal Forests/Taiga -4.495401      0.140490
# 51                                   Southern Congolian forest-savanna  Tropical & Subtropical Grasslands, Savannas & Shrublands -4.488589      0.365264
# 112                                     Trobriand Islands rain forests            Tropical & Subtropical Moist Broadleaf Forests -4.475313      0.012342
# 85                                          Namibian savanna woodlands                                Deserts & Xeric Shrublands -4.439039      0.028169
# 18                                                   Mascarene forests            Tropical & Subtropical Moist Broadleaf Forests -4.404632      0.175141
# 574                        Kamchatka-Kurile meadows and sparse forests                                      Boreal Forests/Taiga -4.348297      0.294805
# 665                                    Great Lakes Basin desert steppe                                Deserts & Xeric Shrublands -4.288233      0.160494
# 209                          Southwest Borneo freshwater swamp forests            Tropical & Subtropical Moist Broadleaf Forests -4.221786      0.000494
# 557                             Altai montane forest and forest steppe                                 Temperate Conifer Forests -4.181811      0.144703
# 239                                     Sumatran tropical pine forests                 Tropical & Subtropical Coniferous Forests -4.098522      0.300000
# 164                                          Borneo peat swamp forests            Tropical & Subtropical Moist Broadleaf Forests -4.098362      0.003460
# 374                                                      Gurupa várzea            Tropical & Subtropical Moist Broadleaf Forests -4.081977      0.017297
# 107                                      Southeast Papuan rain forests            Tropical & Subtropical Moist Broadleaf Forests -4.012095      0.080059
# 41                                      Horn of Africa xeric bushlands  Tropical & Subtropical Grasslands, Savannas & Shrublands -3.941612      0.600000
# 362                                            Chiapas montane forests            Tropical & Subtropical Moist Broadleaf Forests -3.905799      0.214944
# 647   Southwest Iberian Mediterranean sclerophyllous and mixed forests                  Mediterranean Forests, Woodlands & Scrub -3.834843      0.126482
# 203                                 Red River freshwater swamp forests            Tropical & Subtropical Moist Broadleaf Forests -3.834252      0.149633
# 636                                         Illyrian deciduous forests                  Mediterranean Forests, Woodlands & Scrub -3.826473      0.188334
# 98                           Central Range Papuan montane rain forests            Tropical & Subtropical Moist Broadleaf Forests -3.799628      0.247097
# 666                                          Junggar Basin semi-desert                                Deserts & Xeric Shrublands -3.762885      0.249753
# 369                            Eastern Cordillera Real montane forests            Tropical & Subtropical Moist Broadleaf Forests -3.728309      0.028656
# 256                            Sonoran-Sinaloan subtropical dry forest              Tropical & Subtropical Dry Broadleaf Forests -3.720331      0.201631
# 531                                     English Lowlands beech forests                       Temperate Broadleaf & Mixed Forests -3.707015      0.166172
# 540                                 North Atlantic moist mixed forests                       Temperate Broadleaf & Mixed Forests -3.703637      0.228684
# 213                                  Sumatran freshwater swamp forests            Tropical & Subtropical Moist Broadleaf Forests -3.696116      0.189770
# 673                                           Qaidam Basin semi-desert                                Deserts & Xeric Shrublands -3.682021      0.183824
# 394                                            Oaxacan montane forests            Tropical & Subtropical Moist Broadleaf Forests -3.680330      0.128186
# 562                                         Elburz Range forest steppe                                 Temperate Conifer Forests -3.671060      0.251544
# 14                                  Kwazulu Natal-Cape coastal forests            Tropical & Subtropical Moist Broadleaf Forests -3.667437      0.175074
# 518                                    Caspian Hyrcanian mixed forests                       Temperate Broadleaf & Mixed Forests -3.647874      0.177910
# 604                              Central Tibetan Plateau alpine steppe                           Montane Grasslands & Shrublands -3.511613      0.240475
# 149                                               Naracoorte woodlands                  Mediterranean Forests, Woodlands & Scrub -3.495494      0.150309
# 93                                                   Red Sea mangroves                                                 Mangroves -3.487302      0.151948
# 370                                 Eastern Panamanian montane forests            Tropical & Subtropical Moist Broadleaf Forests -3.472009      0.179983
# 140                                 Australian Alps montane grasslands                           Montane Grasslands & Shrublands -3.461152      0.119597
# 145                                               Eyre and York mallee                  Mediterranean Forests, Woodlands & Scrub -3.433374      0.047053
# 588                                        Gissaro-Alai open woodlands               Temperate Grasslands, Savannas & Shrublands -3.432111      0.019283
# 162                                       Andaman Islands rain forests            Tropical & Subtropical Moist Broadleaf Forests -3.428924      0.200000
# 634                                            Iberian conifer forests                  Mediterranean Forests, Woodlands & Scrub -3.398331      0.139140
# 258                             Sierra Madre Oriental pine-oak forests                 Tropical & Subtropical Coniferous Forests -3.397960      0.388628
# 260                               Appalachian mixed mesophytic forests                       Temperate Broadleaf & Mixed Forests -3.366115      0.116803
# 548                          Sichuan Basin evergreen broadleaf forests                       Temperate Broadleaf & Mixed Forests -3.347858      0.104795
# 549                                   Southern Korea evergreen forests                       Temperate Broadleaf & Mixed Forests -3.337314      0.058955
# 246                                  Rann of Kutch seasonal salt marsh                             Flooded Grasslands & Savannas -3.333905      0.181659
# 502                            Northern Mesoamerican Pacific mangroves                                                 Mangroves -3.330881      0.241780
# 638  Mediterranean Acacia-Argania dry woodlands and succulent thickets                  Mediterranean Forests, Woodlands & Scrub -3.314523      0.205340
# 617                                          Yarlung Zanbo arid steppe                           Montane Grasslands & Shrublands -3.312425      0.085714
# 582                   Al-Hajar foothill xeric woodlands and shrublands               Temperate Grasslands, Savannas & Shrublands -3.297138      0.183824
# 262                                     Appalachian-Blue Ridge forests                       Temperate Broadleaf & Mixed Forests -3.291781      0.036139
# 418                                           Veracruz montane forests            Tropical & Subtropical Moist Broadleaf Forests -3.289050      0.040689
# 635                  Iberian sclerophyllous and semi-deciduous forests                  Mediterranean Forests, Woodlands & Scrub -3.248195      0.030161
# 215                                        Sumatran peat swamp forests            Tropical & Subtropical Moist Broadleaf Forests -3.223111      0.041028
# 672                                        Paropamisus xeric woodlands                                Deserts & Xeric Shrublands -3.212131      0.006195
# 450                                                 Bahamian pineyards                 Tropical & Subtropical Coniferous Forests -3.206421      0.080613
# 60                                           Lake Chad flooded savanna                             Flooded Grasslands & Savannas -3.204716      0.337380
# 411                                         Talamancan montane forests            Tropical & Subtropical Moist Broadleaf Forests -3.199865      0.219090
# 201                            Peninsular Malaysian peat swamp forests            Tropical & Subtropical Moist Broadleaf Forests -3.199026      0.203214
# 268                                        Mississippi lowland forests                       Temperate Broadleaf & Mixed Forests -3.162355      0.107761
# 147                                 Jarrah-Karri forest and shrublands                  Mediterranean Forests, Woodlands & Scrub -3.148369      0.390111
# 616                         Western Himalayan alpine shrub and meadows                           Montane Grasslands & Shrublands -3.101558      0.074697
# 255                                              Sunda Shelf mangroves                                                 Mangroves -3.073582      0.080593
# 218                               Taiwan subtropical evergreen forests            Tropical & Subtropical Moist Broadleaf Forests -3.067668      0.518171
# 402                                         Puerto Rican moist forests            Tropical & Subtropical Moist Broadleaf Forests -3.063828      0.362041
# 552                           Tarim Basin deciduous forests and steppe                       Temperate Broadleaf & Mixed Forests -3.051954      0.587879
# 594                             Syrian xeric grasslands and shrublands               Temperate Grasslands, Savannas & Shrublands -3.031718      0.062794
# 447                                           Tumbes-Piura dry forests              Tropical & Subtropical Dry Broadleaf Forests -3.023314      0.169098
# 23                                    Northern Swahili coastal forests            Tropical & Subtropical Moist Broadleaf Forests -3.023150      0.219970
# 186                                      Mindanao montane rain forests            Tropical & Subtropical Moist Broadleaf Forests -3.021753      0.095545
# 679                                                 West Sahara desert                                Deserts & Xeric Shrublands -3.018006      0.078140
# 510                                       Hawai'i tropical dry forests              Tropical & Subtropical Dry Broadleaf Forests -3.009006      0.062934
# 550                                         Taiheiyo evergreen forests                       Temperate Broadleaf & Mixed Forests -3.006988      0.336384
# 676                               Registan-North Pakistan sandy desert                                Deserts & Xeric Shrublands -2.991569      0.241223
# 220                                 Tonle Sap freshwater swamp forests            Tropical & Subtropical Moist Broadleaf Forests -2.978357      0.134520
# 639                             Mediterranean dry woodlands and steppe                  Mediterranean Forests, Woodlands & Scrub -2.967853      0.113170
# 261                                       Appalachian Piedmont forests                       Temperate Broadleaf & Mixed Forests -2.954074      0.063304
# 219              Tenasserim-South Thailand semi-evergreen rain forests            Tropical & Subtropical Moist Broadleaf Forests -2.950333      0.216660
# 205                                  South Taiwan monsoon rain forests            Tropical & Subtropical Moist Broadleaf Forests -2.943467      0.325834
# 187                              Mindanao-Eastern Visayas rain forests            Tropical & Subtropical Moist Broadleaf Forests -2.942510      0.212713
# 533                                   Euxine-Colchic broadleaf forests                       Temperate Broadleaf & Mixed Forests -2.935778      0.176020
# 670                                               North Arabian desert                                Deserts & Xeric Shrublands -2.934164      0.060831
# 661                                      Central Persian desert basins                                Deserts & Xeric Shrublands -2.934085      0.065940
# 208                            Southern Annamites montane rain forests            Tropical & Subtropical Moist Broadleaf Forests -2.926803      0.288191
# 68                                         Ethiopian montane moorlands                           Montane Grasslands & Shrublands -2.918565      0.389474
# 485                                             Southern Andean steppe                           Montane Grasslands & Shrublands -2.916790      0.048949
# 197                              Northern Vietnam lowland rain forests            Tropical & Subtropical Moist Broadleaf Forests -2.908417      0.191300
# 367                                 Costa Rican seasonal moist forests            Tropical & Subtropical Moist Broadleaf Forests -2.902080      0.174171
# 555                                     Zagros Mountains forest steppe                       Temperate Broadleaf & Mixed Forests -2.901195      0.068846
# 413                                   Trinidad and Tobago moist forest            Tropical & Subtropical Moist Broadleaf Forests -2.883056      0.177009
# 669                                          Mesopotamian shrub desert                                Deserts & Xeric Shrublands -2.882718      0.057864
# 497                                                     Sechura desert                                Deserts & Xeric Shrublands -2.882673      0.099480
# 651                                                Arabian sand desert                                Deserts & Xeric Shrublands -2.878920      0.159703
# 4                                            Congolian coastal forests            Tropical & Subtropical Moist Broadleaf Forests -2.870731      0.124970
# 482                                        Cordillera de Merida páramo                           Montane Grasslands & Shrublands -2.869838      0.033333
# 228                                  East Deccan dry-evergreen forests              Tropical & Subtropical Dry Broadleaf Forests -2.860078      0.026225
# 490                                                 Cuban cactus scrub                                Deserts & Xeric Shrublands -2.858529      0.262370
# 206                        South Western Ghats moist deciduous forests            Tropical & Subtropical Moist Broadleaf Forests -2.844198      0.095806
# 654                                    Badghyz and Karabil semi-desert                                Deserts & Xeric Shrublands -2.835039      0.115204
# 570                                   Qionglai-Minshan conifer forests                                 Temperate Conifer Forests -2.824168      0.085559
# 677                            South Arabian plains and plateau desert                                Deserts & Xeric Shrublands -2.819821      0.031683
# 174                                 Hainan Island monsoon rain forests            Tropical & Subtropical Moist Broadleaf Forests -2.817817      0.260095
# 160                                          Tirari-Sturt stony desert                                Deserts & Xeric Shrublands -2.801737      0.068283
# 613                                      Sulaiman Range alpine meadows                           Montane Grasslands & Shrublands -2.796324      0.023190
# 250                                                Indus Valley desert                                Deserts & Xeric Shrublands -2.789958      0.234654
# 227                                Chhota-Nagpur dry deciduous forests              Tropical & Subtropical Dry Broadleaf Forests -2.785157      0.237683
# 183                                                 Luzon rain forests            Tropical & Subtropical Moist Broadleaf Forests -2.771225      0.091047
# 379                                             Jamaican moist forests            Tropical & Subtropical Moist Broadleaf Forests -2.770239      0.212377
# 433                                            Hispaniolan dry forests              Tropical & Subtropical Dry Broadleaf Forests -2.767642      0.160317
# 435                                               Jamaican dry forests              Tropical & Subtropical Dry Broadleaf Forests -2.760188      0.008420
# 561                                East Afghan montane conifer forests                                 Temperate Conifer Forests -2.756882      0.257143
# 405                                        Santa Marta montane forests            Tropical & Subtropical Moist Broadleaf Forests -2.750109      0.050458
# 663                               East Saharan montane xeric woodlands                                Deserts & Xeric Shrublands -2.742885      0.311865
# 675                                  Red Sea-Arabian Desert shrublands                                Deserts & Xeric Shrublands -2.742529      0.424258
# 316                                            Edwards Plateau savanna               Temperate Grasslands, Savannas & Shrublands -2.736615      0.247833
# 498                                           Tehuacán Valley matorral                                Deserts & Xeric Shrublands -2.727160      0.529078
# 263                                         East Central Texas forests                       Temperate Broadleaf & Mixed Forests -2.726608      0.046028
# 188                                               Mindoro rain forests            Tropical & Subtropical Moist Broadleaf Forests -2.695794      0.374321
# 495                                              Paraguaná xeric scrub                                Deserts & Xeric Shrublands -2.691827      0.112516
# 113                                               Vanuatu rain forests            Tropical & Subtropical Moist Broadleaf Forests -2.687173      0.027762
# 323                                           Texas blackland prairies               Temperate Grasslands, Savannas & Shrublands -2.686074      0.092148
# 232                         South Deccan Plateau dry deciduous forests              Tropical & Subtropical Dry Broadleaf Forests -2.674900      0.032681
# 194                    Northern Khorat Plateau moist deciduous forests            Tropical & Subtropical Moist Broadleaf Forests -2.660708      0.325743
# 67                          Ethiopian montane grasslands and woodlands                           Montane Grasslands & Shrublands -2.657554      0.019345
# 429                                       Central American dry forests              Tropical & Subtropical Dry Broadleaf Forests -2.650909      0.000000
# 253                            Indus River Delta-Arabian Sea mangroves                                                 Mangroves -2.650861      0.175597
# 472                                      Everglades flooded grasslands                             Flooded Grasslands & Savannas -2.603777      0.279896
# 399                                        Pernambuco interior forests            Tropical & Subtropical Moist Broadleaf Forests -2.575212      0.070472
# 437                                       Lesser Antillean dry forests              Tropical & Subtropical Dry Broadleaf Forests -2.568008      0.051299
# 184                                        Malabar Coast moist forests            Tropical & Subtropical Moist Broadleaf Forests -2.558251      0.004461
# 407                              Sierra Madre de Chiapas moist forests            Tropical & Subtropical Moist Broadleaf Forests -2.556033      0.008960
# 89                                           Central African mangroves                                                 Mangroves -2.540172      0.005975
# 24                                 Northwest Congolian lowland forests            Tropical & Subtropical Moist Broadleaf Forests -2.536418      0.006478
# 6                                   Cross-Sanaga-Bioko coastal forests            Tropical & Subtropical Moist Broadleaf Forests -2.532682      0.266703
# 167                               Chao Phraya freshwater swamp forests            Tropical & Subtropical Moist Broadleaf Forests -2.530355      0.198116
# 21                                            Nigerian lowland forests            Tropical & Subtropical Moist Broadleaf Forests -2.522091      0.206815
# 5                                       Cross-Niger transition forests            Tropical & Subtropical Moist Broadleaf Forests -2.495267      0.103801
# 1                                           Cameroon Highlands forests            Tropical & Subtropical Moist Broadleaf Forests -2.452133      0.101835
# 48                                   Northern Congolian Forest-Savanna  Tropical & Subtropical Grasslands, Savannas & Shrublands -2.445844      0.171055
# 40                                              Guinean forest-savanna  Tropical & Subtropical Grasslands, Savannas & Shrublands -2.443372      0.095786

# %%
# Biome breakdown of sign disagreements
# Are the sign disagreements concentrated in specific biomes?
print("Biome breakdown of sign disagreement failures:")
print()
print(sign_failures['biome_name'].value_counts().to_string())
# Out:
# Biome breakdown of sign disagreement failures:
#
# biome_name
# Tropical & Subtropical Moist Broadleaf Forests              53
# Deserts & Xeric Shrublands                                  22
# Montane Grasslands & Shrublands                             14
# Temperate Broadleaf & Mixed Forests                         14
# Tropical & Subtropical Dry Broadleaf Forests                12
# Mediterranean Forests, Woodlands & Scrub                    10
# Tundra                                                       9
# Tropical & Subtropical Grasslands, Savannas & Shrublands     7
# Boreal Forests/Taiga                                         6
# Mangroves                                                    6
# Temperate Conifer Forests                                    6
# Temperate Grasslands, Savannas & Shrublands                  5
# Flooded Grasslands & Savannas                                4
# Tropical & Subtropical Coniferous Forests                    3

# %%
fig, ax = plt.subplots(figsize=(9, 7))

for biome, group in df_robust.groupby('biome_name'):
    ax.scatter(group['spearman_rho'], group['slope'],
               color=BIOME_COLOR_MAP[biome], label=biome,
               s=50, edgecolors='black', linewidth=0.5, alpha=0.85)

ax.axhline(0, color='black', linewidth=0.8, linestyle='--')
ax.axvline(0, color='black', linewidth=0.8, linestyle='--')
ax.set_xlabel('Spearman ρ  (per-ecoregion, independent)')
ax.set_ylabel('Mixed model β  (days/°C)')
ax.set_title(f'Robustness Check: Mixed Model β vs Spearman ρ\n{PRIMARY_RESPONSE} ~ {PRIMARY_PREDICTOR}')
ax.legend(fontsize=7, loc='upper left')
ax.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(plot_dir, 'RQ1_robustness_spearman_vs_beta.png'), dpi=150, bbox_inches='tight')
plt.show()

# Overall agreement statistic
rho_vs_beta, p = spearmanr(df_robust['slope'], df_robust['spearman_rho'])
print(f"Agreement between β and ρ across ecoregions: ρ = {rho_vs_beta:.3f}, p = {p:.4f}")
# Out:
# Agreement between β and ρ across ecoregions: ρ = 0.114, p = 0.0029
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\174413052.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 7))

gdf_rob = gdf.merge(df_robust[['eco_id', 'passes_all']], on='eco_id', how='left')
gdf_rob['passes_all'] = gdf_rob['passes_all'].fillna(False)

gdf_rob[~gdf_rob['passes_all']].plot(ax=ax, color='#BDBDBD', linewidth=0.3)
gdf_rob[ gdf_rob['passes_all']].plot(ax=ax, color='#2196F3', linewidth=0.3)

legend_elements = [
    Patch(facecolor='#2196F3', label=f'Passes all checks (n={df_robust["passes_all"].sum()})'),
    Patch(facecolor='#BDBDBD', label=f'Fails ≥1 check   (n={(~df_robust["passes_all"]).sum()})'),
]
ax.legend(handles=legend_elements, fontsize=9, loc='lower left')
ax.set_title(f'Spatial Distribution of Robust Ecoregions\n{PRIMARY_RESPONSE} ~ {PRIMARY_PREDICTOR}',
             fontsize=13, fontweight='bold')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.grid(alpha=0.2)

plt.tight_layout()
plt.savefig(os.path.join(plot_dir, 'rq1_robustness_map.png'), dpi=150, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\2031288037.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf_rob['passes_all'] = gdf_rob['passes_all'].fillna(False)
# C:\Users\ibekar\AppData\Local\Temp\ipykernel_32240\2031288037.py:22: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
